# %% [markdown]
# **Autor:** Andrej Gajdoš  <br>
# *[Ústav matematických vied](https://www.upjs.sk/prirodovedecka-fakulta/ustav/umv/), [Prírodovedecká fakulta](https://www.upjs.sk/prirodovedecka-fakulta/), Univerzita Pavla Jozefa Šafárika v Košiciach,* <br>
# email: [andrej.gajdos@upjs.sk](mailto:andrej.gajdos@upjs.sk)
# ***
# **_Tento materiál vznikol za podpory grantu VVGS-2021-1758._**
# ***
#
# **<font size=6 color=green> MTIb: Téma 1 - Limita funkcie </font>**

# %% [markdown]
# Poďme si postupne predstaviť koncept limity funkcie v danom bode a ukázať si, na čo je to vlastne dobré.

# %% [markdown]
# ---
#
# #### <font color=blue> Príklad (okamžitá rýchosť padajúcej gule - úvod) </font>

# %% [markdown]
# Uvažujme funkciu $s(t)$, ktorá vyjadruje polohu pohybujúceho sa objektu v čase $t$. Konkrétne nech $s(t)=64-16t^2$ je poloha padajúcej gule v čase $t$.

# %%
t =  var('t')
s(t) = 64-16*t^2 
kwds = {'fontsize':12} 
plot(s(t), (t, 0, 2), axes_labels=['$x$', '$y$'], axes_labels_size = 1.2) + text(r"$s(t)=64-16t^2$", (1.3, 50), color='blue',**kwds)
# Out:
# Graphics object consisting of 2 graphics primitives

# %% [markdown]
# Funkcie môžu modelovať ďalšie zaujímavé javy, ako napríklad rýchlosť, akou automobil spotrebúva benzín pri danej rýchlosti, alebo reakcia pacienta na danú dávku lieku. Pomocou nástrojov kalkulu môžeme študovať, ako sa funkčná hodnota mení v závislosti od zmeny vstupnej (nezávislej) premennej.
#
# Ak sa vrátime k funkcii popisujúcej polohu padajúcej gule v čase $t$, tak priemerná rýchlosť ($AV_{\langle 1,x \rangle}$ - Average Velocity) padajúcej gule na intervale $\langle 1,x \rangle$ je daná podielom
#
# $$AV_{\langle 1,x \rangle}=\dfrac{s(x)-s(1)}{x-1}=\dfrac{(64-16x^2)-(64-16\cdot 1)}{x-1}=\dfrac{16-16x^2}{x-1},$$
#
# t.j. celková dráha deleno celkový čas.
#
# Všimnime si, že priemerná rýchlosť je funkciou premennej $x$. Ináč povedané, funkcia $h(x)=\dfrac{16-16x^2}{x-1}$ udáva priemernú rýchlosť gule na intervale od $t=1$ po $t=x$. Aby sme našli okamžitú rýchlosť (tá sa praticky nedá namerať priamo) gule, keď $t = 1$, musíme vedieť, čo sa stane s $h(x)$, keď sa $x$ dostáva bližšie a bližšie k $1$. Ale tiež si všimnime, že $h(1)$ nie je definovaná, pretože vedie k podielu $0/0$.
#
# Tu prichádza na scénu pojem _limity_. Použitím limity môžeme skúmať správanie funkcie $h(x)$, keď sa $x$ približuje ľubovoľne blízko k $1$ ale nerovná sa $1$. Najprv je vhodné pomocou grafu funkcie preskúmať body, v ktorých dochádza k zaujímavému správaniu sa  funkcie.

# %% [markdown]
# ---

# %% [markdown]
# <font color=orange> Predpokladajme, že $g$ je funkcia daná nasledujúcim grafom. Na zodpovedanie každej z nasledujúcich otázok použite tento graf.
#
# ![funkcia_pad_gule_graf.png](attachment:funkcia_pad_gule_graf.png)
# $$\text{Zdroj: Boelkins (2018).}$$
#
# a) Určte funkčné hodnoty $g(-2)$, $g(-1)$, $g(0)$, $g(1)$ a $g(2)$ ak sú definované. Ak hodnota funkcie $g$ v príslušnom bode nie je definovaná, vysvetlite, aká črta grafu funkcie tomu odpovedá.
#
#
# b) Pre každý bod $x_0\in\{-1,0,2\}$ doplňte (miesto troch bodiek) nasledovnú vetu: "Ak sa $x$ približuje k $x_0$ (ale nerovná sa $x_0$), potom sa $g(x)$ blíži k hodnote ... (ľubovoľne blízko)".
#
#
# c) Čo sa deje, keď sa $x$ blíži (ale nerovná sa) k $x_0=1$ ? Bude sa $g(x)$ približovať (ľubovoľne blízko) k jednej konkrétnej hodnote?
#
# </font>

# %% [markdown]
# **Limity nám umožňujú identifikovať trend v hodnotách funkcie, keď sa jej vstupná (nezávislá) premenná približuje k nejakej konkrétnej hodnote.** Potrebujeme presné pochopenie toho, čo to znamená povedať, „funkcia $f$ má limitu $A$, keď sa $x$ blíži k $x_0$.“ Inými slovami, potrebujeme presne vymedziť to, že "$f(x)$ je blízko $A$ keď $x$ je blízko $x_0$" resp., že "s $f(x)$ sa vieme dostať ľubovoľne blízko k hodnote $A$ keď sme s $x$ dostatočne blízko k $x_0$". Presne toto nám formálne a exaktne vystihuje definícia limity uvedená ďalej, avšak ešte pred tým sa vráťme na chvíľu k príkladu funkcie znázornenej na poslednom obrázku.
#
# V predchádzajúcom príklade sme videli (pozri graf), že keď sa $x$ približuje (sprava alebo zľava) stále viac a viac k $0$  (ale nerovná sa $0$), potom hodnota funkcie $g$ sa priblíži tak blízko k hodnote $4$, ako len chceme (ľubovoľne blízko). Na prvý pohľad sa to môže zdať kontraintuitívne (odporujúce našej predstave), pretože hodnota $g(0)$ je $1$, nie $4$. Limity však opisujú správanie funkcie v ľubovoľnej blízkosti pevného vstupu (v tesnej blízkosti nejakého $x_0$) a na hodnote funkcie vo zvolenom pevnom vstupe nezáleží (hodnota $f(x_0)$ nie je podstatná pokiaľ sa jedná o limitu v bode $x_0$). Preto má zmysel definovať niečo ako _prstencové okolie bodu_ $x_0$.
#
# Zavedieme ešte pomocné pojmy a následne vyslovíme definíciu limity funkcie v bode, kde formálne zhrnieme všetky predchádzajúce úvahy.

# %% [markdown]
# ---
#
# ### <font color=red> Definícia 1 </font>
#
# * **_Okolie bodu $x_0$_** ozn. $\mathcal{O}(x_0)$: ľubovoľný otvorený interval obsahujúci bod $x_0$;
#
#
# * **_$\delta$-okolie bodu $x_0$_** ozn. $\mathcal{O}_{\delta}(x_0)$: množina takých bodov $x$ na reálnej osi, ktoré sú vzdialené od bodu $x_0$ o menej ako $\delta$ t.j. $\mathcal{O}_{\delta}(x_0)=\{x\in\mathbb{R}:\,|x-x_0|<\delta\}$, kde $\delta>0$;
#
#
# * **_Prstencové okolie bodu $x_0$_** ozn. $\mathcal{O}^{*}(x_0)$: okolie bodu $x_0$ bez samotného bodu $x_0$ t.j. $\mathcal{O}^{*}(x_0)=\mathcal{O}(x_0) \backslash \{x_0\}$;
#
#
# * **_Prstencové $\delta$-okolie bodu $x_0$_** ozn. $\mathcal{O}^{*}_{\delta}(x_0)$: delta okolie bodu $x_0$ bez samotného bodu $x_0$ t.j. $\mathcal{O}^{*}_{\delta}(x_0)= \mathcal{O}_{\delta}(x_0) \backslash \{x_0\} =\{x\in\mathbb{R}:\,0<|x-x_0|<\delta\}$, kde $\delta>0$;
#
#
# * **_Okolie bodu $+\infty$_** ozn. $\mathcal{O}(+\infty)$: ľubovoľný otvorený interval $(a,+\infty)$, kde $a\in\mathbb{R}$;
#
#
# * **_Okolie bodu $-\infty$_** ozn. $\mathcal{O}(-\infty)$: ľubovoľný otvorený interval $(-\infty,b)$, kde $b\in\mathbb{R}$.
#
# ---

# %% [markdown]
# ---
#
# #### Poznámka 1
#
# * Zrejme funkcia $\sin\,x$ je definovaná na celej reálnej osi tzn. $\forall x\in\mathbb{R}$. Naproti tomu funkcia $\dfrac{\sin\,x}{x}$ nie je definovaná (pozri graf nižšie, prázdny krúžok v $[0,1]$) v bode $x_0=0$ (nula v menovateli zlomku je neprípustná), avšak je definovaná pre každé $x$, ktoré je ľubovoľne blízko k $x_0$ a zároveň je rôzne od $x_0$. Inými slovami to znamená, že funkcia $\dfrac{\sin\,x}{x}$ je definovaná na nejakom prstencovom okolí bodu $x_0$, pričom za prstencové okolie bodu $x_0=0$ funkcie $\dfrac{\sin\,x}{x}$ môžeme vziať napr. interval $(-0.1, 0.1)$ okrem bodu $0$ t.j. $(-0.1, 0.1)\backslash \{0\}$ ale napr. aj $(-0.05, 0.05)\backslash \{0\}$. Navyše z grafu vidíme, že keď sa $x$ blíži k $0$ sprava alebo zľava, tak $f(x)$ sa blíži k hodnote $1$. Číslo $1$ by sme teda nazvali limitou funkcie $\dfrac{\sin\,x}{x}$ v bode $x_0=0$ napriek tomu, že $\dfrac{\sin\,x}{x}$ nie je v bode $x_0=0$ definovaná.

# %%
x =  var('x')
f(x) = sin(x) / x 
kwds = {'fontsize':10} 
p1 = plot(f(x), (x, -2*pi, -0.1), axes_labels=['$x$', '$y$'], axes_labels_size = 1.2) + text(r"$f(x)=\dfrac{\sin\,x}{x}$", (pi, 1), color='blue',**kwds) 
p2 = plot(f(x), (x, 0.1, 2*pi), axes_labels=['$x$', '$y$'], axes_labels_size = 1.2) 
c1 = circle((0,1), 0.1)
# pt1 = point((0, 1), rgbcolor='blue', faceted=True, pointsize=40) 
# show(p1+p2+pt1) , aspect_ratio='automatic'
# show(p1+p2+pt1, aspect_ratio='automatic') 
# show(p1+p2+c1, aspect_ratio=2)
show(p1+p2+c1, figsize=8)
# Out:
# Graphics object consisting of 4 graphics primitives

# %% [markdown]
# ---

# %% [markdown]
# ---
#
# ### <font color=red> Definícia 2 </font>
#
# Nech funkcia $f:\ \mathbb{R} \rightarrow \mathbb{R}$ je definovaná na nejakom okolí bodu $x_0$ (pričom nemusí byť definovaná v $x_0$, tzn. stačí, keď je funkcia definovaná na nejakom prstencovom okolí bodu $x_0$). Hovoríme, že:
#
# funkcia $f$ má v bode $x_0$ **_limitu_** rovnú $A$, ak
#
# $$\left(\forall \varepsilon > 0\right)\left(\exists \delta > 0\right)\left(\forall x \in (x_0 - \delta,x_0+\delta),x\neq x_0\right)\ |f(x)-A| < \varepsilon,$$
#
# funkcia $f$ má v bode $x_0$ **_sprava_** limitu rovnú $A$, ak
#
# $$(\forall \varepsilon > 0)(\exists \delta > 0)(\forall x \in (x_0,x_0+\delta))\ |f(x)-A| < \varepsilon,$$
#
# funkcia $f$ má v bode $x_0$ **_zľava_** limitu rovnú $A$, ak
#
# $$(\forall \varepsilon > 0)(\exists \delta > 0)(\forall x \in (x_0 - \delta,x_0))\ |f(x)-A| < \varepsilon.$$
#
# Limitu $f$ v bode $x_0$ (resp. v bode $x_0$ sprava alebo zľava) označujeme $\lim\limits_{x \to x_0} f(x)$ (resp. $\lim\limits_{x \to x_0+} f(x)$, $\lim\limits_{x \to x_0-} f(x)$).
#
#
# Takto definovaná limita sa zvykne tiež nazývať **_vlastná limita vo vlastnom bode_**.
#
# ---

# %% [markdown]
# ---
#
# #### Poznámka 2
#
# * $x$ sa blíži k $x_0$ zvykneme označovať $x \rightarrow x_0$, $x$ sa blíži k $x_0$ sprava zvykneme označovať $x \rightarrow x_0^+$ a napokon $x$ sa blíži k $x_0$ zľava zvykneme označovať $x \rightarrow x_0^-$.
#
#
# * Definícia limity funkcie v bode nám vlastne hovorí, že s hodnotou $f(x)$ sa vieme priblížiť ľubovoľne blízko k hodnote $A$ (tomu odpovedá v definícii limity $\forall\, \varepsilon > 0:\,|f(x)-A| < \varepsilon$), ak sa s $x$ priblížime dostatočne blízko k $x_0$ tzn. sme v nejakom (malom) vhodnom prstencovom okolí bodu $x_0$ (tomu odpovedá v definícii limity $\exists\, \delta > 0$ také, že $\forall x \in (x_0 - \delta, x_0 + \delta),x\neq x_0$). Všimnime si, že $\varepsilon$ nám udáva akúsi toleranciu resp. maximálnu vzdialenosť $f(x)$ od $A$ na nejakom malom okolí bodu $x_0$. Inými slovami, ak funkcia $f$ má limitu $A$ v bode $x_0$, tak nech zvolíme $\varepsilon>0$ akokoľvek malé, vždy je možné nájsť k nemu také $\delta$, že pre $x$ z tohto prstencového delta okolia bodu $x_0$ bude platiť $|f(x)-A|<\varepsilon$, tzn. zmenšovaním $\varepsilon$ sa teda vieme dostať s $f(x)$ ľubovoľne blízko ($|f(x)-A|$ vyjadruje vzdialenosť $f(x)$ od $A$) k hodnote $A$ na nejakom okolí bodu $x_0$.
#
#
#
# * Limita sprava hovorí o približovaní sa k $x_0$ po reálnej osi len sprava a teda pozeráme sa na tzv. _pravé prstencové okolie_ bodu $x_0$ t.j. $(x_0,x_0+\delta)$. Podobne limita zľava hovorí o približovaní sa k $x_0$ po reálnej osi iba zľava a teda pozeráme sa na tzv. _ľavé prstencové okolie_ bodu $x_0$ t.j. $(x_0+\delta,x_0)$.
#
#
# * Jednostranná limita v bode $x_0$ teda slúži na skúmanie správania sa funkcie buď napravo alebo naľavo od bodu $x_0$ t.j. skúmame správanie sa funkcie keď sa k $x_0$ približujeme buď sprava alebo zľava. Limita funkcie v bode $x_0$ v sebe zahŕňa obidva tieto prípady.
#
#
# * Ešte je dôležité si uvedomiť, že **v definícii limity, to $\delta$, ktoré tam vystupuje, závisí jednak od zvoleného $\varepsilon$ ale tiež od bodu $x_0$, v ktorom limitu hľadáme**. Ak by sme chceli byť úplne striktní a dôleslední, mohli by sme písať, že $\delta (x_0, \varepsilon)$, nezvykne sa to však robiť, no majme to na pamäti.
#
#
# * Z vlastností absolútnej hodnoty vyplýva, že výraz $|f(x)-A|<\varepsilon$ v definícii limity môžeme ekvivalentne prepísať takto: $A-\varepsilon < f(x) < A+\varepsilon$. Toto vyjadrenie nám vlastne hovorí o páse šírky $2\varepsilon$ okolo hodnoty $A$ ($\varepsilon$-vzdialenosť smerom nahor od $A$, $\varepsilon$-vzdialenosť smerom nadol od $A$), v ktorom ležia funkčné hodnoty $f(x)$, ak $x$ je z dostatočne malého okolia bodu $x_0$. Tvar $A-\varepsilon < f(x) < A+\varepsilon$ nás priamo navádza ku geometrickej interpretácii limity (pozri obrázok a interaktívny kód nižšie).
#
#
# * Podmienku $\forall x \in (x_0 - \delta,x_0+\delta),x\neq x_0$ v Definícii 2 je možné ekvivalentne vyjadriť takto: $\forall x\in\mathcal{D}(f):0<|x-x_0|<\delta$.
#
# ---

# %% [markdown]
# Nasledujúca Veta dáva do súvisu limitu s jednostrannými limitami. Niekedy pri výpočte limity funkcie v danom bode môže byť užitočné určiť jednostranné limity a keď sa budú rovnať tej istej hodnote, potom to číslo môžeme prehlásiť za limitu funkcie v danom bode - pozri príklad s funkciou $\dfrac{\sin x}{x}$ v Poznámke 1. Platí však aj opačný postup. t.j. ak poznáme limitu funkcie v danom bode, potom z toho vieme určiť jednostranné limity. **Navyše obmena Vety 1 sa dá v mnohých prípadoch vyžiť aj k tomu, aby sme ukázali, že limita danej funkcie v určitom bode neexistuje. Stačí ukázať, že jednostranné limity sú rôzne, tzn. limita zľava je rôzna od limity sprava (viď Príklad 1 nižšie).**

# %% [markdown]
# ---
#
# ### <font color=green> Veta 1 </font>
#
# Funkcia $f$ má v bode $x_0$ limitu rovnú $A$ práve vtedy, keď má bode $x_0$ limitu sprava aj zľava a  obidve tieto limity sú rovné $A$.
#
# ---

# %% [markdown]
# Ďalej **Veta 2 hovorí o tom, že ak už funkcia má limitu, tak je jediná (je určená jednoznačne). Obdobné tvrdenie platí aj pre jednostranné limity.**

# %% [markdown]
# ---
#
# ### <font color=green> Veta 2 </font>
#
# Funkcia $f$ má v bode $x_0$ nanajvýš jednu limitu (nanajvýš jednu limitu sprava, nanajvýš jednu limitu zľava).
#
# ---

# %% [markdown]
# ---
#
# #### <font color=blue> Príklad 1 </font>
#
# Vráťme sa k príkladu s funkciou $g(x)$, ktorá je znázornená na obrázku.
#
# ![funkcia_pad_gule_graf.png](attachment:funkcia_pad_gule_graf.png)
# $$\text{Zdroj: Boelkins (2018).}$$
#
# Z grafu môžeme ľahko vyčítať, že platí
#
# $$\lim\limits_{x \to -1} g(x)=3, \qquad\qquad \lim\limits_{x \to 0} g(x)=4, \qquad\qquad \lim\limits_{x \to 2} g(x)=1.$$
#
# Keď sa snažíme určiť limitu funkcie pomocou jej grafu, stačí overiť, či sa funkčné hodnoty $f(x)$ blížia k jednej a tej istej hodnote $A$ sprava aj zľava keď sa $x$ blíži k (fixnému) $x_0$ sprava aj zľava. V prípade troch limít uvedených vyššie je najprv $x_0=-1$, $A=3$, potom $x_0=0$, $A=4$ a nakoniec $x_0=2$, $A=2$.
#
# Avšak funkcia $g$ znázornená na obrázku nemá limitu keď  $x \rightarrow1 $. V bode $x_0=1$ je v grafe funkcie skok. Keď sa blížime k $x_0=1$ zľava tak funkčné hodnoty $g(x)$ sa blížia k hodnote $3$ ale keď sa blížime k $x_0=1$ sprava tak funkčné hodnoty $f(x)$ sa blížia k hodnote $2$. Neexistuje jedno a to isté číslo, ku ktorému by sa tieto funkčné hodnoty blížili (keď sa približujeme k $x_0=1$). To je dôvod, prečo funkcia $g$ nemá v bode $x_0=1$ limitu.
#
# ---

# %% [markdown]
# ---
#
# #### Poznámka 3
#
# Pre akúkoľvek funkciu $f$ existujú zvyčajne tri spôsoby, ako odpovedať na otázku „má $f$ limitu v bode $x=x_0$, a ak áno, aká je limita?“ Prvým spôsobom je zdôvodnenie na základe grafu funkcie $f$, ako sme to urobili v Príklade 1. Ak poznáme predpis funkcie $f$, existujú dve ďalšie možnosti:
#
# 1. Vypočítať funkčné hodnoty pre postupnosť bodov (vstupov), ktoré sa približujú k fixnému $x_0$ z jednej alebo druhej strany, t.j. sprava alebo zľava (zvyčajne s použitím softvéru), a sledovať, či sa odpovedajúca postupnosť funkčných hodnôt (výstupov) približuje k jednej a tej istej hodnote $A$ alebo nie.
#
#
# 2. Využiť predpis funkcie $f$ a jej vlastnosti na to, aby sme zistili aký je trend vo funkčných hodnotách, ktoré zodpovedajú vstupom blížiacim sa k fixnému $x_0$.
#
# Uvedomme si však, že prvý zmienený prístup je len približný pre určenie limity funkcie v danom bode a nie exaktný !!! Druhý spôsob častokrát vedie k presnému výpočtu / určeniu limity funkcie v danom bode.
#
# ---

# %% [markdown]
# ---
#
# #### <font color=blue> Príklad 2 </font>
#
# Pri každej z nasledujúcich funkcií by sme chceli vedieť, či funkcia má alebo nemá limitu pre uvedené hodnoty $x_0$. Na preskúmanie použite numerické aj algebraické prístupy a ak je to možné, odhadnite alebo určte hľadané limity. Výsledky porovnajte s grafom príslušnej funkcie na intervale obsahujúcom body záujmu.
#
# $$\text{a) } f(x) = \dfrac{4-x^2}{x+2};\,x_0=-1,\,x_0=-2 \qquad\qquad \text{b) } g(x) = \sin\,\left(\dfrac{\pi}{x}\right);\,x_0=3,\,x_0=0$$
#
# <ins> Riešenie: <ins/>
#
# a) Najprv sa pozrieme na graf funkcie $f$ v blízkosti bodov $-1$ a $-2$ a tiež na funkčné hodnoty $f(x)$ keď je $x$ bízko pri $-1$ a pri $-2$.

# %%
x =  var('x')
f(x) = (4-x^2) / (x+2) 
kwds = {'fontsize':12} 
p1 = plot(f(x), (x, -3, -2.1), axes_labels=['$x$', '$y$'], axes_labels_size = 1.2) + text(r"$f$", (-2.2, 4.7), color='blue',**kwds) 
p2 = plot(f(x), (x, -1.9, 2), axes_labels=['$x$', '$y$'], axes_labels_size = 1.2) 
c1 = circle((-2,4), 0.1, color = 'black')
show(p1+p2+c1)
# Out:
# Graphics object consisting of 4 graphics primitives

# %%
# vypis hodnot f(x), ked je x blizko -1 (zlava i sprava) 
# vypis je v tvare (x, f(x))
z1 = [-0.9,-0.99,-0.999,-0.9999,-1.1,-1.01,-1.001,-1.0001]
[(z1[i],f(z1[i])) for i in range(0,len(z1))]
# Out:
# [(-0.900000000000000, 2.90000000000000),
#  (-0.990000000000000, 2.99000000000000),
#  (-0.999000000000000, 2.99900000000000),
#  (-0.999900000000000, 2.99990000000000),
#  (-1.10000000000000, 3.10000000000000),
#  (-1.01000000000000, 3.01000000000000),
#  (-1.00100000000000, 3.00100000000000),
#  (-1.00010000000000, 3.00010000000000)]

# %%
# vypis hodnot f(x), ked je x blizko -2 (zlava i sprava) 
# vypis je v tvare (x, f(x))
z2 = [-1.9,-1.99,-1.999,-1.9999,-2.1,-2.01,-2.001,-2.0001]
[(z2[i],f(z2[i])) for i in range(0,len(z2))]
# Out:
# [(-1.90000000000000, 3.90000000000000),
#  (-1.99000000000000, 3.98999999999998),
#  (-1.99900000000000, 3.99899999999986),
#  (-1.99990000000000, 3.99990000000061),
#  (-2.10000000000000, 4.10000000000000),
#  (-2.01000000000000, 4.00999999999998),
#  (-2.00100000000000, 4.00100000000014),
#  (-2.00010000000000, 4.00009999999939)]

# %% [markdown]
# Z výpisu hodnôt sa zdá, že s hodnotu $f$ sa vieme dostať ľubovoľne blízko k hodnote $3$ ak vezmeme $x$ dostatočne blízko k $-1$ a to nás nabáda k tomu, že $\lim\limits_{x \to -1} f(x)=\lim\limits_{x \to -1} \dfrac{4-x^2}{x+2}=3$. Tento záver je v zhode s grafom funkcie $f$. Pozrime sa na to trochu exaktnejšie a z algebraického (resp. analytického) pohľadu, teda využijeme predpis funkcie $f(x)=\dfrac{4-x^2}{x+2}$. Keď $x\rightarrow-1$, potom $(4-x^2)\rightarrow\left(4-(-1)^2\right)=3$ a $(x+2)\rightarrow(-1+2)=1$, čiže ak $x\rightarrow-1$, potom hodnota čitateľa zlomku v predpise funkcie $f$ sa blíži k $3$ a hodnota menovateľa zlomku v predpise funkcie $f$ sa blíži k $-1$, preto $\lim\limits_{x \to -1} f(x)=\lim\limits_{x \to -1} \dfrac{3}{1}=3$.
#
# Trochu zložitejšia je situácia keď $x\rightarrow-2$ lebo $f(-2)$ nie je definované (nula v menovateli zlomku). Ak by sme skúsili analogicý algebraický prístup ako v predošlom prípade, tak pre $x\rightarrow-2$ máme $(4-x^2)\rightarrow(4-(-2)^2)=0$ a $(x+2)\rightarrow(-2+2)=0$, čiže keď $x\rightarrow-2$, potom čitateľ aj menovateľ zlomku v predpise funkcie $f$ sa blížia k $0$, čím vzniká tzv. _nedefinovaný výraz_ v tvare $0/0$. To naznačuje, že treba urobiť ešte čosi iné, coši viac, aby sme vypočítali limitu v bode $-2$, ak taká limita existuje. Na druhej strane z grafu funkcie $f$ a z výpisu funkčných hodnôt (viď hore) v blízkom okolí $2$ sa zdá, že funkcia $f$ by mala mať v bode $2$ limitu rovnú hodnote $4$. <br/>
# Pozrime sa na to algebraicky ale trochu ináč. Keď skúmame limitu funkcie $f(x)=\dfrac{4-x^2}{x+2}$ v bode $-2$, tak nás vlastne zaujíma správanie sa tejto funkcie v (ľubovoľnej) tesnej blízkosti bodu $-2$, nikdy nie však priamo v bode $-2$. Všimnime si, že keď vo výraze $\dfrac{4-x^2}{x+2}=\dfrac{(2-x)(2+x)}{x+2}$ vykrátime výraz $(x+2)$ (ktorý je v súčine v čitateli zlomku a tiež v menovateli zlomku), tak dostaneme výraz $2-x$. Funkcia $f(x)=\dfrac{4-x^2}{x+2}=\dfrac{(2-x)(2+x)}{x+2}$ a funkcia $2-x$ sa rovnajú na celej realnej osi s výnimkou bodu $-2$, keďže tam fukcia $f$ definovaná nie je, zatiaľ čo funkcia $2-x$ áno. Pri skúmaní limity funkcie $f$ v bode $-2$ ale funkčná hodnota v samotnom bode $-2$ nie je dôležitá, pohybujeme sa totiž len na prstencovom okolí (podľa definíce limity) bodu $-2$ (t.j. okrem bodu $-2$), preto pri výpočte tejto limity môžeme miesto funkcie $f$ uvažovať ďalej funkciu $2-x$, ktorá vznikla po vykrátení. Na základe týchto úvah môžeme písať
#
# $$\lim\limits_{x \to -2} f(x)=\lim\limits_{x \to -1} (2-x)=4.$$
#
# Túto poslednú uvedenú limitu už ľahko určíme (či už z grafu funkcie $2-x$ alebo cez postupnosť jej funkčných hodnôt v blízkosti bodu $-2$) a teda $\lim\limits_{x \to -2} f(x)=4$.
#
# Správnosť výpočtu limít môžeme overiť aj vstavanou Sage funkciou `limit`, tak ako to ilustruje nasledujúci kód. **Pri výpočte limít by mal byť človek pozorný, nespoliehať sa iba na softvér ale použiť aj vlastný rozum!** V niektorých zložitejších prípadoch môže softvér zlyhať alebo môže poskytnúť nesprávny výsledok. Veľakrát sa tomu dá predísť, ale vyžaduje si to skúsenejšieho a rozmýšľajúceho užívateľa, ktorý zadá nejaké doplňujúce predpoklady či obmedzenia (reštrikcie) pri výpočte limity.

# %%
print(limit(f(x), x=-1)) # limita f(x) pre x-> -1
print(limit(f(x), x=-2)) # limita f(x) pre x-> -2
# Out:
# 3
# 4

# %% [markdown]
# b) Najprv sa pozrieme na graf funkcie $g$ v blízkosti bodov $3$ a $0$ a tiež na funkčné hodnoty $g(x)$ keď je $x$ bízko pri $3$ a pri $0$.

# %%
x =  var('x')
g(x) = sin(pi / x)
kwds = {'fontsize':12} 
p3 = plot(g(x), (x, -3, -0.05), axes_labels=['$x$', '$y$'], axes_labels_size = 1.2) + text(r"$g$", (2, 1.2), color='blue',**kwds) 
p4 = plot(g(x), (x, 0.05, 3), axes_labels=['$x$', '$y$'], axes_labels_size = 1.2) 
c2 = circle((0,0), 0.05, color = 'black')
show(p3+p4+c2)
# Out:
# Graphics object consisting of 4 graphics primitives

# %%
# vypis hodnot g(x), ked je x blizko 3 
z3 = [2.9,2.99,2.999,2.9999,3.1,3.01,3.001,3.0001]
[(z3[i],n(g(z3[i]))) for i in range(0,len(z3))]
# Out:
# [(2.90000000000000, 0.883512044446023),
#  (2.99000000000000, 0.867771255204052),
#  (2.99900000000000, 0.866199942106655),
#  (2.99990000000000, 0.866042857131103),
#  (3.10000000000000, 0.848644257494751),
#  (3.01000000000000, 0.864280635353575),
#  (3.00100000000000, 0.865850876294908),
#  (3.00010000000000, 0.866007950546102)]

# %%
# vypis hodnot g(x) ked je x blizko 0  
z4 = [-0.1,-0.01,-0.001,-0.0001,0.1,0.01,0.001,0.0001]
[(z4[i],n(g(z4[i]))) for i in range(0,len(z4))]
# Out:
# [(-0.100000000000000, 1.22464679914735e-15),
#  (-0.0100000000000000, -1.96438672372847e-15),
#  (-0.00100000000000000, 3.21416645927563e-13),
#  (-0.000100000000000000, 4.85682353956849e-13),
#  (0.100000000000000, -1.22464679914735e-15),
#  (0.0100000000000000, 1.96438672372847e-15),
#  (0.00100000000000000, -3.21416645927563e-13),
#  (0.000100000000000000, -4.85682353956849e-13)]

# %% [markdown]
# Pre $x \rightarrow3 $ nám výpis funkčných hodnôt $g(x)$ pre $x$ v blízkosti $3$ naznačuje, že funkcia $g$ sa blíži k nejakému číslu približne (po zaokrúhlení) medzi $0.86601$ a $0.86604$. Z grafu funkcie $g$ sa zdá, že $g(x)\rightarrow g(3)$ keď $x\rightarrow3$. Presná hodnota $g(3)=\sin\left(\dfrac{\pi}{3}\right)$ je $\dfrac{\sqrt{3}}{2}$ (pozri jednotkovú kružnicu, graf alebo tabuľky), čo je približne $0.8660254038$. To nás vedie k záveru, že
#
# $$\lim\limits_{x \to 3} g(x) = \lim\limits_{x \to 3} \sin\left(\dfrac{\pi}{3}\right) = \dfrac{\sqrt{3}}{2}. $$
#
# Všimnime si, že keď $x \rightarrow 0$ tak výraz $\dfrac{\pi}{x}$ sa nespráva celkom "štandardne". Keď je $x>0$ a blíži sa k $0$ (sprava), tak delíme číslo $\pi$ stále menším a menším kladným číslom (blízkym nule), čo spôsobuje, že hodnota zlomku $\dfrac{\pi}{x}$ rastie nad všetky hodnoty až do $+\infty$. Na druhej strane, keď je $x<0$ a blíži sa k $0$ (zľava) tak hodnota zlomku klesá pod všetky medze až do $-\infty$. V tomto zmysle teda keď sa $x$ blíži k $0$ tak vstupy v tvare $\dfrac{\pi}{x}$ pre funkciu sínus sa rapídne zväčšujú (resp. zmenšujú) a to vedie k rapídne sa zväčšujúcim osciláciám grafu funkcie $g(x)=\sin\,\left(\dfrac{\pi}{x}\right)$ medzi hodnotami $-1$ a $1$. Osciláciami rozumieme "divoké" vlnenie sa grafu funkcie (pripomínajúce akoby rýchle kmity medzi) medzi $-1$ a $1$ v okolí bodu $0$ (viď graf hore). Pri vykreslení grafu funkcie $g$ v na malom okolí bodu $0$ (vykreslite si!) je vidieť, že sa funkčná hodnota nikdy neustáli okolo nejakého jedného čísla v blízkosti počiatku súradnicovej sústavy. Toto nás vedie k záveru, že funkcia $g$ nemá v bode $x_0=0$ limitu.
#
# Ako ale zladiť to, čo napovedá graf funkcie $g$ s výpisom funkčných hodnôt v okolí nuly (pozri hore), ktorý naznačuje, že limita $g$ pre $x \rightarrow 0$ by mohla byť $0$ ? Výpis funkčných hodnôt je v tomto prípade zavádzajúci kvôli špeciálnemu tvaru (povahe) zvolenej postupnosti hodnôt $\{0.1,0.001,0.0001,\ldots\}$ v blízkosti nuly. Členy tejto postunposti sú vlastne čísla v tvare $10^{-k}$, kde $k$ ide cez prirodzené čísla. Keď vypočítame $g(10^{-k})=\sin\,\left(\dfrac{\pi}{10^{-k}}\right)=\sin\,(10^{k}\pi)=0$ pre každé $k\in\mathbb{N}$ (pozri jednotkovú kružnicu, graf alebo tabuľky). Keď ale vezmeme inú postupnosť čísel (bodov) v blízkosti nuly, napr. postupnosť $\{0.3,0.03,0.003,\ldots\}$, čo sú vlastne čísla v tvare $3\cdot10^{-k},\,k\in\mathbb{N}$, tak zistíme, že
#
# $$g(3\cdot10^{-k})=\sin\,\left(\dfrac{\pi}{3\cdot10^{-k}}\right)=\sin\,\left(\dfrac{10^k\pi}{3}\right)=\dfrac{\sqrt{3}}{2}\approx 0.866025.$$
#
# Táto postupnosť funkčných hodnôt nám na rozdiel od predošlej postupnosti podsúva myšlienku, že by limita funkcie $g$ v bode $0$ mohla byť $\dfrac{\sqrt{3}}{2}$. **Podľa vety o jednoznačnosti limity (Veta 2) ale vieme, že to nie je možné aby funkcia mala v jednom bode dve limity zodpovedajúce rôznym číslam.** Preto funkcia $g$ nemá limitu pre $x \rightarrow 0$.
#
# Výpis funkčných hodnôt v okolí nejakého bodu môže byť užitočný na preskúmanie správania funkcie v okolí daného bodu, no nie je možné sa na neho na 100% spoľahnúť a určiť limitu iba na jeho základe. Ako sme videli v tomto príklade, pri určení/výpočte limity je potrebné využiť aj iné nástroje (prípadne ich skombinovať).
#
# Na záver tohto príkladu ešte kontrolný výpočet limít funkcie $g$ pomocou Sage.

# %%
print(limit(g(x), x=3)) # limita g(x) pre x-> 3, presny vysledok (symbolicky) 
print(n(limit(g(x), x=3))) # limita g(x) pre x-> 3, priblizny vysledok (numericky)
print(limit(g(x), x=0)) # limita g(x) pre x-> 0, tato limita neexistuje
# Out:
# 1/2*sqrt(3)
# 0.866025403784439
# ind

# %% [markdown]
# <font color=orange> Inšpirujte sa Príkladom 2 a) v učebnom texte. Pomocou výpisu funkčných hodnôt pre $x$ blíko $x_0$ (v Sage) odhadnite hodnotu každej z limít uvedených nižšie, kde $x_0$ predstavuje bod, v ktorom sa ráta limita príslušnej funkcie. Presnú hodnotu limít určte na základe algebraického (analytického) prístupu za pomoci zjednodušenia funkcií ak je to potrebné a možné. Pri úprave/zjednodušovaní funkcií môžete použiť aj Sage ale mali by ste vedieť pomenovať aspoň myšlienku/úpravu, ktorá sa pri zjednodušení využila. Na záver vykreslite každú z funkcií na vhodnom intervale aby ste vizuálne (graficky) overili vypočítané limity.
#
# $$\text{a) } \lim\limits_{x \to 1} \dfrac{x^2-1}{x-1} \qquad\qquad \text{b) } \lim\limits_{x \to 0} \dfrac{(2+x)^3-8}{x} \qquad\qquad \text{c) } \lim\limits_{x \to 0} \dfrac{\sqrt{x+1}-1}{x}$$
# </font>

# %% [markdown]
# ---

# %% [markdown]
# ---
#
# #### <font color=blue> Príklad 3 (okamžitá rýchosť padajúcej gule - dokončenie) </font>
#
# V úvode tejto témy sme videli, že priemernú rýhlosť padajúcej gule v čase od $1$ po $x$ časových jednotiek t.j. na intervale $\langle 1, x  \rangle$ môžeme vyjadriť funkciou
#
# $$AV_{\langle 1,x \rangle}=h(x)=\dfrac{16-16x^2}{x-1}.$$
#
# Okamžitá rýchlosť padajúcej gule v čase $t=1$ ozn. $IV_{t=1}$ sa definuje ako limita funkcie $h(x)$ udávajúcej priemernú rýchlosť keď sa $x$ blíži k $1$. Predstavme si postupnosť takých $x$, ktoré sa blížia k $1$ a tomu odpovedá postupnosť funkčných hodnôt $h(x)$, ktorá sa približuje k okamžitej rýchlosti v čase $t=1$. Všimnime si, že keď $x \rightarrow 1$ tak časový interval na ktorom uvažujeme priemernú rýchlosť $h(x)$ sa skracuje. Na základe týchto úvah pre okamžitú rýchlosť padajúcej gule v čase $t=1$ platí
#
# $$IV_{t=1}=\lim\limits_{x \to 1} AV_{\langle 1,x \rangle} = \lim\limits_{x \to 1} \dfrac{s(x)-s(1)}{x-1} = \lim\limits_{x \to 1} h(x) = \lim\limits_{x \to 1} \dfrac{16-16x^2}{x-1}=\lim\limits_{x \to 1} \dfrac{-16(x^2-1)}{x-1} = \lim\limits_{x \to 1} \dfrac{-16(x-1)(x+1)}{x-1} = \lim\limits_{x \to 1} -16(x+1)=-32.$$
#
# Okamžitá rýchlosť padajúcej gule v čase $t=1$ je $32$ (napr. m/s alebo nejaká iná jednotka).
# Záporné znamienko (rýchlosť je vektor tzn. má smer aj veľkosť, v tomto prípade je to jednorozmerný vektor) len hovorí o tom, že guľa padá smerom nadol (pohybuje sa v opačnom resp. "zápornom" smere).
# Všimnime si ešte, že na výpočet tejto limity sme použili podobnú úvahu i algebraickú úpravu ako v Príklade 2.
# Kľúčovou myšlienkou je to, že na výpočet okamžitej rýchlosti berieme limitu priemerných rýchlostí, keď sa časový interval skracuje. Tento typ limity je v praxi a v aplikáciách veľmi dôležitý, preto má aj samostatné pomenovanie (derivácia) a bude mu venovaná  jedna z ďalších tém v rámci tohto kurzu.
#
# ---

# %% [markdown]
# **Geometrický význam vlastnej limity v bode**: pre každú šírku pásu (rovnú $2\varepsilon$, kde $\varepsilon$ je vzdialenosť okraja pásu od jeho pozdĺnej osi) s horizontálnou osou $y = A$ existuje okolo bodu $x_0$ interval polomeru $\delta$ taký, že úsek grafu funkcie (červená krivka) vymedzený krajnými bodmi tohto intervalu leží celý vnútri daného pásu. Toto musí platiť pre každy taký pás šírky $2\varepsilon$ okolo priamky $y=A$, ak $A$ je limita danej funkcie v bode $x_0$. To isté vlastne hovorí **definícia limity funkcie v bode** t.j. $\left(\forall \varepsilon > 0\right)\left(\exists \delta > 0\right)\left(\forall x \in (x_0 - \delta,x_0+\delta),x\neq x_0\right)\ |f(x)-A| < \varepsilon$ resp. **ekvivalentné vyjadrenie** $\left(\forall \varepsilon > 0\right)\left(\exists \delta > 0\right)\left(\forall x\in\mathcal{D}(f):0<|x-x_0|<\delta\right)\ |f(x)-A| < \varepsilon$.
#
# ![limita_geometricky2.png](attachment:limita_geometricky2.png)
# $$\text{Zdroj: Madaras (2019).}$$

# %% [markdown]
# ---
#
# #### Poznámka 4
#
# V prípade jednostranných limít t.j. limity sprava resp. limity zľava by nás zaujímali iba tie $x$, ktoré sú napravo od $x_0$ resp. naľavo od $x_0$, teda tie, ktoré su z tzv. **_pravého okolia_** bodu $x_0$ t.j. $(x_0,x_0+\delta)$ resp. z **_ľavého okolia_** bodu $x_0$ t.j. $(x_0-\delta,x_0)$. Pre obrázok vyššie by to znamenalo, že zo sivého pásu by sme odrezali časť naľavo od $x_0$ resp. napravo od $x_0$.
#
# ---

# %% [markdown]
# **Definíciu limity a jej geometrickú interpretáciu si môžete výskúšať spustením nasledovného interaktívneho kódu**, ktorý má tieto vstupné parametre: $f$ - funkcia, ktorej limitu skúmame; $x_{min}$ a $x_{max}$ - určujú rozsah na osi $x$, kde sa má vykresliť graf funkcie $f$; $x_0$ - bod, v ktorom skúmame (hľadáme) limitu funkcie $f$; $A$ - náš tip, čo by mohla byť limita funkcie $f$ v bode $x_0$; $\varepsilon$ - polovica šírky priehľadného horizontálneho pásu okolo hodnoty $A$, ohraničeného dvoma prerušovanými čiarami (t.j. okolie bodu $y=A$); $\delta$ - polovica šírky ružového vertikálneho pásu okolo bodu $x_0$, ohraničeného dvoma prerušovanými čiarami (t.j. okolie bodu $x_0$).
#
# **Princíp experimentovania je nasledovný:** Zadajte nejakú funkciu $f$; nastavte rozumný interval pomocou $x_{min}$ a $x_{max}$, na ktorom sa má vykresliť graf funkcie $f$; zvoľte bod $x_0$, v ktorom chcete skúmať (hľadať) limitu danej funkcie $f$; potom odhadnite, aká by podľa Vás mohla byť limita funkcie $f$ v bode $x_0$ tzn. zadajte hodnotu $A$; ďalej zvoľte nejaké (malé) $\varepsilon>0$ a následne skúšajte k zvolenému $\varepsilon$ nájsť (malú) hodnotu $\delta>0$ (či existuje) takú, aby graf funkcie $f$ nezasahoval do ružového pásu (ale aby bol "stlačený" v priesvitnom $\varepsilon$-páse). Ak funkcia $f$ má v bode $x_0$ limitu $A$, potom ku každému $\varepsilon>0$ by ste mali vedieť nájsť také vhodné $\delta>0$. To je len inými slovami prerozprávaná definícia limity. Samozrejme, nie je prakticky možné vyskúšať ku každému $\varepsilon>0$ (je ich nekonečne veľa) nájsť vhodné $\delta>0$ (overiť definíciu limity na 100%) ale podstatné je porozumieť, čo nám definícia limity hovorí, ako ju vieme experimentálne overovať (aj keď nie na 100%) a ako to vyzerá geometricky.

# %%
# created by John Perry
# modified by A.G. 

pretty_print(html("<h2>Limits: <i>ε-δ</i></h2>"))
pretty_print(html("This allows you to estimate which values of <i>δ</i> guarantee that <i>f</i> is within <i>ε</i> units of a limit."))
pretty_print(html("<ul><li>Modify the value of <i>f</i> to choose a function.</li>"))
pretty_print(html("<li>Modify the value of <i>x0</i> to change the <i>x</i>-value where the limit is being estimated.</li>"))
pretty_print(html("<li>Modify the value of <i>A</i> to change your guess of the limit.</li>"))
pretty_print(html("<li>Modify the values of <i>δ</i> and <i>ε</i> to modify the rectangle.</li></ul>"))
pretty_print(html("If the blue curve passes through the pink boxes, your values for <i>δ</i> and/or <i>ε</i> are probably wrong."))
@interact
def delta_epsilon(f = input_box(default=(x^2-x)/(x-1), label="$f$"), xm=input_box(label=r"$x_{min}$",default=-1), xM=input_box(label=r"$x_{max}$",default=4), a=input_box(default=1, label="$x_0$"), L = input_box(default=1, label="$A$"), epsilon=input_box(label=r"$\varepsilon$",default=0.1), delta=input_box(label=r"$\delta$",default=0.1)):
    f_left_plot = plot(f,xm,a-delta/3,thickness=2)
    f_right_plot = plot(f,a+delta/3,xM,thickness=2)
    epsilon_line_1 = line([(xm,L-epsilon),(xM,L-epsilon)], rgbcolor=(0.5,0.5,0.5),linestyle='--')
    epsilon_line_2 = line([(xm,L+epsilon),(xM,L+epsilon)], rgbcolor=(0.5,0.5,0.5),linestyle='--')
    ym = min(f_right_plot.ymin(),f_left_plot.ymin())
    yM = max(f_right_plot.ymax(),f_left_plot.ymax())
    bad_region_1 = polygon([(a-delta,L+epsilon),(a-delta,yM),(a+delta,yM),(a+delta,L+epsilon)], rgbcolor=(1,0.6,0.6))
    bad_region_2 = polygon([(a-delta,L-epsilon),(a-delta,ym),(a+delta,ym),(a+delta,L-epsilon)], rgbcolor=(1,0.6,0.6))
    aL_point = point((a,L),rgbcolor=(1,0,0),pointsize=20)
    delta_line_1 = line([(a-delta,ym),(a-delta,yM)],rgbcolor=(0.5,0.5,0.5),linestyle='--')
    delta_line_2 = line([(a+delta,ym),(a+delta,yM)],rgbcolor=(0.5,0.5,0.5),linestyle='--')
    (f_left_plot +f_right_plot +epsilon_line_1 +epsilon_line_2 +delta_line_1 +delta_line_2 +aL_point +bad_region_1 +bad_region_2).show(xmin=xm,xmax=xM)
# Out:
# <h2>Limits: <i>ε-δ</i></h2>
# This allows you to estimate which values of <i>δ</i> guarantee that <i>f</i> is within <i>ε</i> units of a limit.
# <ul><li>Modify the value of <i>f</i> to choose a function.</li>
# <li>Modify the value of <i>x0</i> to change the <i>x</i>-value where the limit is being estimated.</li>
# <li>Modify the value of <i>A</i> to change your guess of the limit.</li>
# <li>Modify the values of <i>δ</i> and <i>ε</i> to modify the rectangle.</li></ul>
# If the blue curve passes through the pink boxes, your values for <i>δ</i> and/or <i>ε</i> are probably wrong.
# Interactive function <function delta_epsilon at 0x6fc5661a1e0> with 7 widgets
#   f: EvalText(value='(x^2 - x)/(…

# %% [markdown]
# Teraz, keď už máme aj dobrú geometrickú predstavu o tom, čo je to limita funkcie resp. ako ju experimentálne geometricky hľadať (na základe definície limity), môžeme si ukázať spôsob **ako dokázať, že nejaké číslo je limitou danej funkcie**. Ako ilustrujú  nasledujúce dva príklady, je možné pri tom vychádzať **priamo z definície limity funkcie v bode**.

# %% [markdown]
# ---
#
# #### <font color=blue> Príklad 4 </font>
#
# Z definície limity dokážte, že $\lim\limits_{x \to 4} \sqrt{x} = 2$.
#
# <ins> Riešenie: <ins/>
#
# Pred tým, než použijeme formálnu definíciu, urobme niekoľko konkrétnych numerických experimentov, aby sme lepšie porozumeli, o čo ide. Vezmime najprv $\varepsilon=0.5$, ako blízko (aké ma byť delta?) musí byť $x$ k bodu $x_0=2$, aby $2-\varepsilon <  f(x) < 2+\varepsilon$ t.j. $2-0.5 <  f(x) < 2+0.5$ t.j. $1.5 <  f(x) < 2.5$ ? Ináč povedané, pre aké $\delta$, ak zoberieme ľubovoľné $x\in(4-\delta,4+\delta)\backslash\{2\}$ bude platiť $1.5 <  f(x) < 2.5$ ? Môžeme to zistiť nasledovne:
#
# \begin{align*}
# 1.5 <\,  & f(x) < 2.5 \\
# 1.5 <\, & \sqrt(x) < 2.5 \\
# (1.5)^2 <\, & x < (2.5)^2 \\
# 2.25 <\, & x < 6.25
# \end{align*}
#
# Aké má byť teda $\delta$ pre $\varepsilon=0.5$ ? Hľadáme $\delta$ tak aby sme dostali symetrický interval so stredom v $x_0=4$ t.j. $4-\delta < x < 4+\delta$ resp. $(4-\delta,4+\delta)$. Z nerovností uvedených vyššie máme, že musí platiť $2.25<x$ a tomu  odpovedá $4-\delta < x$, odtiaľ $4-\delta>2.25$, čo dáva $\delta<1.75$. Na druhej strane z nerovností uvedených vyššie tiež máme, že musí platiť $x<6.25$ a tomu odpovedá $x<4+\delta$, čo dáva spolu $6.25>4+\delta$ a teda $\delta<2.25$. V našom prípade potrebujeme vybrať len jedno $\delta$ a konkrétne vyberieme $\delta$ menšie ako minimum z dvoch ponúkajúcich sa hodnôt, t.j. $\delta<\min\{1.75,2.25\}=1.75$. Minimum berieme preto, aby boli dodržané hranice pre $x$, ktoré sme vypočítali vyššie, konkrétne $2.25 < x < 6.25 $. Toto zrejme bude splnené, keď vezmeme $\delta<1.75$ a potom máme $2.25<x<5.75$. Inými slovami, ak vezmeme ľubovoľné $x\in(2.25,5.75)\backslash\{4\}$, potom pre každé také $x$ bude platiť $1.5 <  f(x) < 2.5$. <font color=orange> Overte to pomocou interaktívneho kódu ! Taktiež skúste v interaktívnom kóde zobrať $\delta$ ako maximum z čísel $1.75$ a $2.25$ miesto minima a všimnite si, prečo také $\delta$ nie je vhodné. </font>
#
# Vezmime teraz $\varepsilon=0.01$. Aké by malo byť v tomto prípade $\delta$ aby pre každé $x\in(4-\delta,4+\delta)\backslash\{2\}$ platilo $2-\varepsilon <  f(x) < 2+\varepsilon$ t.j. $2-0.01 <  f(x) < 2+0.01$ t.j. $1.99 < f(x) < 2.01$ ? <font color=orange> Nájdite vhodné $\delta$ pre $\varepsilon=0.01$ rovnakým prístupom ako v prípade $\varepsilon=0.5$. Taktiež to overte pomocou interaktívneho kódu. </font>
#
# Uvažujme teraz vo všeobecnosti nejaké $\varepsilon>0$. Predpokladajme, že $f(x)=\sqrt{x}$ je v $\varepsilon$-páse tzn. $|f(x)-2|<\varepsilon$ resp. ekvivalentne $2-\varepsilon<f(x)<2+\varepsilon$. Upravujme ďalej:
#
# \begin{align*}
# |f(x)-2|<&\varepsilon \\
# -\varepsilon<f(x)-2<&\varepsilon\\
# -\varepsilon<\sqrt{x}-2<&\varepsilon \\
# 2-\varepsilon<\sqrt{x}<&2+\varepsilon \\
# (2-\varepsilon)^2<x<&(2+\varepsilon)^2 \\
# 4-4\varepsilon+\varepsilon^2<x<&4+4\varepsilon+\varepsilon^2 \\
# 4-(4\varepsilon-\varepsilon^2)<x<&4+(4\varepsilon+\varepsilon^2).
# \end{align*}
#
# Posledný krok (nerovnosti), to je len úprava do vhodného tvaru v zmysle "$4-\text{ niečo}<x<4+\text{ niečo}$". Podobne ako v predošlých prípadoch s konkrétnymi hodnotami pre $\varepsilon$, nám teraz posledné nerovnosti ponúkajú dve možnosti pre hľadané $\delta$ t.j. $\delta<4\varepsilon-\varepsilon^2$ alebo $\delta<4\varepsilon+\varepsilon^2$, pričom z nich opäť vyberieme minimum, t.j. $\delta<\min\{4\varepsilon-\varepsilon^2,4\varepsilon+\varepsilon^2\}$ aby boli splnené obe požadované nerovnosti $4-(4\varepsilon-\varepsilon^2)<x<4+(4\varepsilon+\varepsilon^2)$. Keďže $\varepsilon>0$ tak minimum je $4\varepsilon-\varepsilon^2$ a teda potrebujeme zvoliť $\delta<4\varepsilon-\varepsilon^2$.
#
# Keď do tohto všeobecného vyjadrenia $\delta<4\varepsilon-\varepsilon^2$ dosadíme $\varepsilon = 0.5$ alebo $\varepsilon = 0.01$ tak dostaneme tú istú nerovnosť pre hľadané $\delta$ k príslušnému $\varepsilon$ ako v konkrétnych príkladoch vyššie. <font color=orange> Overte to! </font>
#
# Práve sme dokázali nasledovné: <br/>
# Ak zvolíme ľubovoľné $\varepsilon>0$ a k nemu vezmeme $\delta<4\varepsilon-\varepsilon^2$, tak potom pre $|x-4|<\delta, x\neq4$ bude platiť $|f(x)-2|<\varepsilon$, čo znamená, že je spĺnená definícia limity funkcie $f(x)=\sqrt{x}$ v bode $x_0=4$ tzn. platí
#
# $$\lim\limits_{x \to 4} \sqrt{x} = 2.$$
#
# ---

# %% [markdown]
# ---
#
# #### <font color=blue> Príklad 5 </font>
#
# Z definície limity dokážte, že $\lim\limits_{x \to 1} \dfrac{x^2-1}{x - 1} = 2$.
#
# <ins> Riešenie: <ins/>
#
#  Chceme dokázať , že
#
#  $$(\forall \varepsilon > 0)(\exists \delta > 0)(\forall x \in (1 - \delta,1+\delta),x\neq 1)\ \left|\dfrac{x^2-1}{x - 1}-2\right| < \varepsilon.$$
#
#  Nech $\varepsilon > 0$ je ľubovoľné. Položme $\delta = \varepsilon$. Potom pre všetky $x \in (1 - \delta, 1+\delta), x \neq 1$ je $|x-1| < \delta = \varepsilon$; ďalej platí $|x-1| = |x+1 - 2| = \left| \dfrac{(x+1)(x-1)}{x-1} -2 \right| = \left|\dfrac{x^2-1}{x-1} - 2\right|$. Teda je $\left|\dfrac{x^2-1}{x-1} - 2\right| < \varepsilon$.
#
#
# Všimnime si malé triky, ktoré sme využili pri úpravách vyššie. Najprv sme $-1$ napísali ako $-1=1-2$ a potom sme výraz $x+1$  vynásobili "vhodnou jednotkou" t.j. $x+1=(x+1)\cdot 1=(x+1)\cdot\dfrac{x-1}{x-1}$.
#
# ---

# %% [markdown]
# <font color=orange> Preskúmajte (podobne ako v Príklade 2 a)) pomocou Sage, ako sa správa funkcia z predošlého príkladu v (pravom aj ľavom) okolí bodu $x_0=1$ a využite aj interaktívny kód v učebnom texte pre experimentálne overenie limity v tomto bode - tzn. zvoľte si niekoľko hodnôt pre epsilon, napr. $\varepsilon\in\{0.5, 0.25, 0.1, 0.05\}$. a ku každému z nich nájdite vhodné $\delta>0$ tak, aby bola splnená definícia limity v bode $x_0=1$ resp. aby bol dodržaný princíp experimentovania popísaný nad interaktívnym kódom. </font>

# %% [markdown]
# <font color=orange> Pomocou interaktívneho kódu preskúmajte správanie funkcie $y=\sin\frac{1}{x}$ v okolí bodu $x_0=0$ (ide o podobnú funkciu ako Príklade 2 b) ). Zvoľte vhodné parametre a experimentujte (napr. $x_{min}=-0.5$, $x_{max}=0.5$, $A=0$, $\varepsilon=0.5$ a pre $\delta$ vyskúšajte rôzne hodnoty ako napr. $\delta\in\{0.5,0.4,0.3,0.2,0.1\}$). Pokúšajte sa meniť hodnoty parametrov interaktívneho kódu - zvoľte si nejaké rozumné hodnoty pre $A$ (hodnota potenciálnej limity), $\varepsilon$ (okolie hodnoty $A$). Následne pre zvolené $A$, $\varepsilon$ skúšajte rôzne hodnoty pre $\delta$ a pozorujte, čo sa deje. Prečo nie je pre funkciu $y=\sin\frac{1}{x}$ splnená definícia limity v bode $x_0=0$ ? Urobte experimenty pre niekoľko rôznych (zmysluplných) hodnôt $A$, $\varepsilon$, ku ktorým budete skúšať rôzne (zmysluplné) hodnoty pre $\delta$ a zamýšľajte sa, prečo nie je splnená definícia limity resp. to, čo je uvedené v popise experimentovania nad interaktívnym kódom. </font>

# %% [markdown]
# Nasledujúce **tvrdenia (vety)** sú **užitočné pri výpočte určitých typov limít (tiež jednostranných)**. Uvedomme si, že **odhad limity na základe grafu funkcie resp. na základe numerických aproximácii (výpis funkčných hodnôt v blízkosti nejakého bodu) je veľmi užitočný a veľakrát i názorný ale nie je to exaktný spôsob výpočtu resp. argumentácie! Môže to poslúžiť na získanie určitej predstavy o správaní sa funkcie resp. na odhad limity, aby sme mali tušenie, k čomu sa máme dopracovať rigoróznym postupom, tzn. dôkaz z definície limity (viď vyššie) alebo využitie matematických tvrdení (viet). Nezabúdajme, že ak chceme aplikovať nejaké tvrdenie pri výpočte konkrétnej limity, potrebujeme najprv overiť (na papieri a/alebo pomocou Sage), či sú splnené predpoklady tvrdenia, ktoré chceme využiť. Teda či sme v situácii, o ktorej dané tvrdenie pojednáva, teda či je možné ho použiť.**
#
# Napr. Veta 3 hovorí, že polynomické funkcie sú pekné okrem iného aj v tom, že limitu z polynomickej funkcie $p(x)$ pre $x\to x_0$ vypočítame priamym dosadením bodu $x_0$ do predpisu funkcie a teda výsledná limita je rovná funkčnej hodnote $p(x_0)$.

# %% [markdown]
# ---
#
# ### <font color=green> Veta 3 </font>
#
# Nech $p(x)$ a $q(x)$ sú polynomické funkcie a nech $x_0$ je reálne číslo. Potom platí:
#
# 1. $\lim\limits_{x\to x_0} p(x)=p(x_0)$;
#
#
# 2. $\lim\limits_{x\to x_0} \dfrac{p(x)}{q(x)} = \dfrac{p(x_0)}{q(x_0)}$, kde $q(x_0)\neq0$.
#
# ---

# %% [markdown]
# ---
#
# ### <font color=green> Veta 4 </font>
#
# Nech funkcia $f$ má v bode $x_0$ limitu rovnú $A$ a funkcia $g$ má v bode $x_0$ limitu rovnú $B$. Potom
#
# a) $\lim\limits_{x \to x_0} |f(x)| = |A|$;
#
#
# b) $\lim\limits_{x \to x_0} c\cdot f(x) = cA$;
#
#
# c) $\lim\limits_{x \to x_0} (f(x) \pm g(x)) = A \pm B$;
#
#
# d) $\lim\limits_{x \to x_0} (f(x) \cdot g(x)) = A\cdot B$;
#
#
# e) ak $B \neq 0$, tak $\lim\limits_{x \to x_0} \dfrac{f(x)}{g(x)} = \dfrac{A}{B}$;
#
#
# f) $\lim\limits_{x \to x_0} (f(x))^n = A^n$, kde $n\in\mathbb{N}$;
#
#
# g) $\lim\limits_{x \to x_0} \sqrt[n]{f(x)} = \sqrt[n]{A}$, kde $n\in\mathbb{N}$, pričom ak $n$ je nepárne tak musí byť $f(x)\ge0$ na nejakom okolí bodu $x_0$.
#
# ---

# %% [markdown]
# ---
#
# #### <font color=blue> Príklad 6 </font>
#
# Nech $\lim\limits_{x \to 2} f(x)=2$ a $\lim\limits_{x \to 2} g(x)=3$. Vypočítajte $\lim\limits_{x \to 2} \left(5f(x)+g(x)^2\right)$.
#
# <ins> Riešenie: <ins>
#
# S využitím pravidiel b), c) a d) resp. f) z Vety 4 dostávame
#
# $$\lim\limits_{x \to 2} \left(5f(x)+g(x)^2\right)=5\cdot2+3^2=19.$$
#
# ---

# %% [markdown]
# ---
#
# ### <font color=green> Veta 5 </font>
#
# Nech funkcia $f$ má v bode $x_0$ limitu rovnú $A$, funkcia $g$ má v bode $A$ limitu rovnú $B$ a nech pre všetky $x$ z nejakého prstencového okolia bodu $x_0$ platí $f(x) \neq A$. Potom
#
# $$\lim\limits_{x \to x_0} (g \circ f)(x) = \lim\limits_{x \to x_0} g(f(x)) = B.$$
#
# ---

# %% [markdown]
# ---
#
# #### <font color=blue> Príklad 7 </font>
#
# Nech $f(x) = 5x^2$ a $g(x)=\cos\,x$. Vypočítajte $\lim\limits_{x \to 0} g(f(x))$.
#
# <ins> Riešenie: <ins>
#
# Ľahko nahliadneme (Veta 3), že $\lim\limits_{x \to 0} f(x)=\lim\limits_{x \to 0} 5x^2=0$ a pre každé $x \neq 0$ z  ľubovoľného otvoreného intervalu so stredom v bode $0$ platí, že $f(x) \neq 0$.
#
# Zrejme $(g \circ f)(x)=\cos(5x^2)$, preto podľa Vety 5 máme
#
# $$\lim\limits_{x \to 0} g(f(x))=\lim\limits_{x \to 0} \cos(5x^2)=\cos(0)=1=\lim\limits_{x \to 0} \cos x.$$

# %%
x =  var('x')
f(x) = cos(5*x^2)  
kwds = {'fontsize':12} 
p1 = plot(f(x), (x, -2, 2), axes_labels=['$x$', '$y$'], axes_labels_size = 1.2) + text(r"$f(x)=\cos(5x^2)$", (0.5, 1.2), color='blue',**kwds) 
show(p1)
# Out:
# Graphics object consisting of 2 graphics primitives

# %% [markdown]
# ---

# %% [markdown]
# Ďalšia veta pojednáva o tom, že **ak vieme funkciu $h$ ohraničiť zdola aj zhora nejakými funkciami $f$ a $g$, pričom funkcie $f$ a $g$ majú rovnakú limitu, potom aj funkcia $h$ "zovretá" funkciami $f$, $g$ má rovnakú limitu ako oni**.

# %% [markdown]
# ---
#
# ### <font color=green> Veta 6  (O zovretí resp. princíp stláčania) </font>
#
# Nech $\lim\limits_{x \to x_0} f(x) = \lim\limits_{x \to x_0} g(x) = A$ a nech existuje také prstencové okolie $x_0$, že pre všetky $x$ z tohto okolia platí $f(x) \leq h(x) \leq g(x)$. Potom $\lim\limits_{x \to x_0} h(x) = A$.
#
# ---

# %% [markdown]
# ---
#
# #### <font color=blue> Príklad 8 </font>
#
# Nech $h(\theta)=\dfrac{\sin\theta}{\theta}$. Vypočítajte $\lim\limits_{\theta \to 0} h(\theta)$.
#
# <ins> Riešenie: <ins/>
#
# Využijeme známe fakty z goniometrie (bez zdôvodnenia), konkrétne pre ľubovoľný uhol $\theta$ platí (viď obrázky):
#
# $$\sin\theta\le\theta\le\tan\theta.$$
#
# ![finta_priklad_sqthm.png](attachment:finta_priklad_sqthm.png)
# $$\text{Zdroj: www.mathwarehouse.com.}$$
#
# Upravujme nerovnosti $\sin\theta\le\theta\le\tan\theta$ ďalej pomocou ekvivalentných úprav, s cieľom ohraničiť funkciu $h(\theta)=\dfrac{\sin\theta}{\theta}$ zdola nejakou funkciou $f(\theta)$, zhora nejakou funkciou $g(\theta)$, pričom potrebujeme vedieť ukázať, že $\lim\limits_{\theta \to 0} f(\theta)=\lim\limits_{\theta \to 0} g(\theta)$.
#
# \begin{align*}
# \sin\theta & \le\theta\le\tan\theta \\
# \sin\theta & \le\theta\le\dfrac{\sin\theta}{\cos\theta} \\
# \dfrac{\sin\theta}{\sin\theta} & \le\dfrac{\theta}{\sin\theta}\le\dfrac{\sin\theta}{\cos\theta}\cdot\dfrac{1}{\sin\theta} \\
# 1 & \le \dfrac{\theta}{\sin\theta}\le\dfrac{1}{\cos\theta} \\
# 1 & \ge \dfrac{\sin\theta}{\theta}\ge\cos\theta
# \end{align*}
#
# Na nejakom prstencovom okolí bodu $0$ vieme funkciu $h(\theta)$ vtesnať resp. "stlačiť" medzi funkcie $f(\theta)$ a $g(\theta)$, ináč povedané, vieme funkciu $h(\theta)$ ohraničiť funkciami $f(\theta)$ a $g(\theta)$ (viď graf nižšie). <br/>
# Nemalo by byť ťažké vidieť, že $\lim\limits_{\theta\to0}1=\lim\limits_{\theta\to0}\cos\theta=1$. Podľa Vety 7 teda platí aj
# $\lim\limits_{\theta\to0} \dfrac{\sin\theta}{\theta}=1$.

# %%
theta =  var('theta', latex_name="\\theta")
h(theta) = sin(theta)/theta  
kwds = {'fontsize':12} 
p1 = plot(h(theta), (x, -25, 25), axes_labels=['$\\theta$', '$y$'], axes_labels_size = 1.2) + text(r"$h(\theta)=\sin(\theta)/\theta$", (10, 1), color='blue',**kwds) 
show(p1)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
theta =  var('theta', latex_name="\\theta")
h(theta) = sin(theta)/theta  
g(x) = 1
f(x) = cos(theta)
kwds = {'fontsize':12} 
p1 = plot(h(theta), (theta, -0.5, 0.5), axes_labels=['$\\theta$', '$y$'], axes_labels_size = 1.2) + text(r"$h(\theta)=\sin\,\theta/\theta$", (0.7, 0.96), color='blue',**kwds) 
p2 = plot(g(theta), (theta, -0.5, 0.5), axes_labels=['$\\theta$', '$y$'], axes_labels_size = 1.2, color = 'red') + text(r"$g(\theta)=1$", (0.7, 1), color='red',**kwds) 
p3 = plot(f(theta), (theta, -0.5, 0.5), axes_labels=['$\\theta$', '$y$'], axes_labels_size = 1.2, color = 'green') + text(r"$f(\theta)=\cos\,\theta$", (0.7, 0.88), color='green',**kwds) 
show(p1+p2+p3)
# Out:
# Graphics object consisting of 6 graphics primitives

# %% [markdown]
# **K Príkladu 8 ešte pripájame interaktívny kód**, kde je možné si všimnúť a odkrokovať, čo sa deje na jednotkovej kružnici, keď $\theta\to0$.

# %%
# created by Wai Yan Pong 

# x=var('x')
theta =  var('theta', latex_name="\\theta")
@interact
def _(theta = slider(-7/10,7/10,1/20,1/2)):
    pretty_print(html(r'<h3>A graphical illustration of $\lim_{\theta -> 0} \sin(\theta)/\theta =1$</h3>'))
    pretty_print(html(r'Below is the unit circle, so the length of the <font color=red>red line</font> is $|\sin(\theta)|$'))
    pretty_print(html(r'and the length of the <font color=blue>blue line</font> is $|\tan(\theta)|$ where $\theta$ is the length of the arc.'))
    pretty_print(html(r'From the picture, we see that $|\sin(\theta)|$ $\le$ $|\theta|$ $\le$ $|tan(\theta)|$.'))
    pretty_print(html(r'It follows easily from this that $\cos(\theta) \le sin(\theta)/\theta \le 1$ when $x$ is near $0$.'))
    pretty_print(html(r'As $\lim_{\theta ->0} \cos(\theta) =1$, we conclude that $\lim_{\theta -> 0} \sin(\theta)/\theta =1$.'))
    if not (theta == 0):
        pretty_print("sin(theta) / theta = "+str(sin(float(theta))/float(theta)))
    elif theta == 0:
        pretty_print("The limit of sin(\theta)/\theta as \theta tends to 0 is 1.")
    C=circle((0,0),1, rgbcolor='black')
    mvp = (cos(theta),sin(theta));tpt = (1, tan(theta))
    p1 = point(mvp, pointsize=30, rgbcolor='red'); p2 = point((1,0), pointsize=30, rgbcolor='red')
    line1 = line([(0,0),tpt], rgbcolor='black'); line2 = line([(cos(theta),0),mvp], rgbcolor='red') 
    line3 = line([(0,0),(1,0)], rgbcolor='black'); line4 = line([(1,0),tpt], rgbcolor='blue')
    result = C+p1+p2+line1+line2+line3+line4
    result.show(aspect_ratio=1, figsize=[3,3], axes=False)
# Out:
# Interactive function <function _ at 0x6fc55f18e18> with 1 widget
#   theta: SelectionSlider(description='theta',…

# %% [markdown]
# ---

# %% [markdown]
# ---
#
# ### <font color=green> Veta 7 </font>
#
# Ak $\lim\limits_{x \to x_0} f(x) = 0$ a ak existuje také okolie $x_0$, že funkcia $g$ je na ňom ohraničená, tak $\lim\limits_{x \to x_0} f(x)g(x) = 0$.
#
# ---

# %% [markdown]
# ---
#
# #### <font color=blue> Príklad 9 </font>
#
# Nech $f(x)=4x^3\cdot\cos x$. Vypočítajte $\lim\limits_{x\to0} f(x)$.
#
# <ins> Riešenie: <ins/>
#
# Zrejme $\lim\limits_{x\to0} 4x^3 = 0$ (podľa Vety 3) a $\cos x$ je ohraničená funkcia, ktorá nadobúda hodnoty od $-1$ po $1$. Podľa Vety 7 teda platí $\lim\limits_{x\to0} 4x^3\cdot\cos x=0$.

# %%
x =  var('x')
f(x) = 4*x^3*cos(x)  
kwds = {'fontsize':12} 
p1 = plot(f(x), (x, -2, 2), axes_labels=['$x$', '$y$'], axes_labels_size = 1.2) + text(r"$f(x)=4x^3\cdot\cos x$", (1.5, 5), color='blue',**kwds) 
show(p1)
# Out:
# Graphics object consisting of 2 graphics primitives

# %% [markdown]
# ---

# %% [markdown]
# ### Kedy funkcia nemá vlastnú limitu vo vlastnom bode?

# %% [markdown]
# Je niekoľko situácii, kedy funkcia nemá limitu v nejakom bode $x_0$, tzn. keď $x \rightarrow x_0$ tak $f(x)$ sa neblíži k jednému konkrétnemu číslu. Môžu to byť napr. tieto tri časté prípady:
#
# 1. Hodnoty funkcie $f(x)$ sa môžu blížiť k dvom rôznym číslam, v závislosti od toho či $x \rightarrow x_0$ sprava alebo zľava (o tomto pojednáva Veta 1);
#
# 2. Funkcia môže rásť nad všetky medze ($f(x)$ ide do $+\infty$) alebo klesať pod všetky možné hodnoty ($f(x)$ ide do $-\infty$), keď $x \rightarrow x_0$;
#
# 3. Funkcia môže oscilovať bez toho, aby sa jej hodnoty blížili k jednému konkrétnemu číslu, keď $x \rightarrow x_0$ (viď Príklad 2 časť b) alebo funkcia v Príklade 12 ).
#
# Každú z uvedených možností budeme po poradí ilustrovať na príklade.

# %% [markdown]
# ---
#
# #### <font color=blue> Príklad 10 </font>
#
# Uvažujme funkciu $f(x)=\begin{cases}
# \ x^2-2x+3, \qquad x \le 1\\
# \ x, \qquad\qquad\quad x > 1
# \end{cases}$.
# Chceme ukázať, že limita v bode $x_0=1$ neexistuje.
# Môžeme pri tom využiť obmenu Vety 1, ktorá má rovnakú pravdivostnú hodnotu ako Veta 1 a znie takto: "Keď sa jednostranné limity funkcie $f$ v bode $x_0$ líšia, potom limita funkcie $f$ v bode $x_0$ neexistuje."
#
# <ins> Riešenie: <ins/>
#
# Keď ukážeme, že jednostranné limity funkcie $f$ v bode $x_0=1$ sa líšia, potom podľa obmeny Vety 1 dostaneme záver, že limita funkcie $f$ v bode $x_0=1$ neexistuje. Z grafu funkcie $f$ a z výpisu jej funkčných hodnôt na blízkom pravom a ľavom okolí bodu $1$ je vidieť, že f(x) sa neblíži k jednému a tomu istému číslu, keď $x \rightarrow 1$ sprava a keď $x \rightarrow 1$ zľava. V prvom prípade $f(x) \rightarrow 1$, v druhom prípade $f(x) \rightarrow 2$. Na tieto jednostranné limity vieme použiť a argumentovať aj Vetou 3, keďze tu máme polynomické funkcie.

# %%
x =  var('x') 
f1 = x^2-2*x+3
f2 = x
p1 = plot(f1(x), (x, 0, 1), axes_labels=['$x$', '$y$'], axes_labels_size = 1.2) 
p2 = plot(f2(x), (x, 1.02, 2), axes_labels=['$x$', '$y$'], axes_labels_size = 1.2)
c1 = circle((1,1), 0.03, color = 'blue')
pt1 = point((1, 2), rgbcolor='blue', pointsize=50)
show(p1+p2+c1+pt1)
# Out:
# Graphics object consisting of 4 graphics primitives

# %%
# f(x) ked x blizko 1 
f = piecewise([([-100,1], x^2-2*x+3), ((1,100), x)])
z1 = [0.9,0.99,0.999,0.9999,1.0001,1.001,1.01,1.1]
[(z1[i],f(z1[i])) for i in range(0,len(z1))]
# Out:
# [(0.900000000000000, 2.01000000000000),
#  (0.990000000000000, 2.00010000000000),
#  (0.999000000000000, 2.00000100000000),
#  (0.999900000000000, 2.00000001000000),
#  (1.00010000000000, 1.00010000000000),
#  (1.00100000000000, 1.00100000000000),
#  (1.01000000000000, 1.01000000000000),
#  (1.10000000000000, 1.10000000000000)]

# %% [markdown]
# ---

# %% [markdown]
# ---
#
# #### <font color=blue> Príklad 11 </font>
#
# Preskúmajme, prečo $\lim\limits_{x \to 1} \dfrac{1}{(x-1)^2}$ neexistuje.
#
# <ins> Riešenie: <ins/>
#
# Graf funkcie $f(x)=\dfrac{1}{(x-1)^2}$ aj výpis funkčných hodnôt v blízkom okolí bodu $1$ naznačujú, že funkcia $f$ rastie v blízkosti jednotky do nekonečna. Všimnime si, že priamka $x=1$ je vlastne vertikálna asympota uvedenej funkcie.

# %%
x =  var('x') 
f = 1 / (x-1)^2
p1 = plot(f(x), (x, 0, 0.9), axes_labels=['$x$', '$y$'], axes_labels_size = 1.2) 
p2 = plot(f(x), (x, 1.1, 2), axes_labels=['$x$', '$y$'], axes_labels_size = 1.2)
l1 = line([(1,0),(1,100)], color = 'black', linestyle = 'dashed')
show(p1+p2+l1)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
z2 = [0.9,0.99,0.999,0.9999,1.0001,1.001,1.01,1.1]
[(z2[i],f(z2[i])) for i in range(0,len(z2))]
# Out:
# /opt/sagemath-9.0/local/lib/python3.7/site-packages/sage/repl/ipython_kernel/__main__.py:2: DeprecationWarning: Substitution using function-call syntax and unnamed arguments is deprecated and will be removed from a future release of Sage; you can use named arguments instead, like EXPR(x=..., y=...)
# See http://trac.sagemath.org/5930 for details.
#   from sage.repl.ipython_kernel.kernel import SageKernel
# [(0.900000000000000, 100.000000000000),
#  (0.990000000000000, 9999.99999999998),
#  (0.999000000000000, 999999.999999998),
#  (0.999900000000000, 1.00000000000022e8),
#  (1.00010000000000, 1.00000000000022e8),
#  (1.00100000000000, 1.00000000000022e6),
#  (1.01000000000000, 9999.99999999998),
#  (1.10000000000000, 99.9999999999998)]

# %% [markdown]
# ---

# %% [markdown]
# ---
#
# #### <font color=blue> Príklad 12 </font>
#
# <font color=orange> Preskúmajte, prečo $\lim\limits_{x \to 0} \sin\,\left(\dfrac{1}{x}\right)$ neexistuje. Využite Sage a postup aplikovaný v Príklade 2 v časti b). </font>

# %% [markdown]
# ---

# %% [markdown]
# **V ďalšej časti sa pozrieme typy limít, keď samotná limita nie je číslo ale je to buď $+\infty$ alebo $-\infty$** (funkcia nadobúda v blízkosti nejakého bodu veľmi veľkú alebo veľmi malú hodnotu, ktorá prekračuje všetky medze) a tiež na situáciu, keď miesto bodu $x_0$ sa $x$ blíži k väčším a väčším hodnotám resp. k stále menším hodnotám, t.j. $x\to+\infty$ alebo $x\to-\infty$. <br/>
# Pozrime sa napr. na funkciu $f(x)=\dfrac{1}{x^2}$ (alebo aj na fuknciu v Príklade 11).

# %%
x =  var('x')
kwds = {'fontsize':12} 
f = 1 / x^2
p1 = plot(f(x), (x, -1, -0.1), axes_labels=['$x$', '$y$'], axes_labels_size = 1.2) + text(r"$f(x)=\dfrac{1}{x^2}$", (0.5, 20), color='blue',**kwds)
p2 = plot(f(x), (x, 0.1, 1), axes_labels=['$x$', '$y$'], axes_labels_size = 1.2) 
show(p1+p2)
# Out:
# Graphics object consisting of 3 graphics primitives

# %% [markdown]
# Vidíme, že ak $x$ v aboslútnej hodnote je príliš veľké t.j. $|x|$ je príliš veľké (tzn. buď $x\to+\infty$ alebo $x\to-\infty$), tak $f(x)$ je veľmi malé, blízke nule. Pre takéto prípady budeme použivať označenie $\lim\limits_{x\to+\infty} f(x)=\lim\limits_{x\to+\infty} \dfrac{1}{x^2}=0$ resp. $\lim\limits_{x\to-\infty} f(x)=\lim\limits_{x\to-\infty} \dfrac{1}{x^2}=0$. Na druhej strane keď $x\to0$, tak $f(x)$ je veľmi veľké a rastie nad všetky medze. Pre tento typ limít budeme používať označenie $\lim\limits_{x\to0} f(x) = \lim\limits_{x\to0} \dfrac{1}{x^2} = +\infty$. Poďme si tieto pojmy exaktne definovať a bližšie rozobrať.

# %% [markdown]
# ---
#
# ### <font color=red> Definícia 3 </font>
#
# Nech funkcia $f$ je definovaná na nejakom prstencovom okolí bodu $x_0$ (tzn. nemusí byť definovaná v $x_0$).  Hovoríme, že:
#
# funkcia $f$ má v bode $x_0$ **_nevlastnú limitu_** $+\infty$, ak
# $$(\forall c \in \mathbb{R})(\exists \delta > 0)(\forall x \in (x_0 - \delta,x_0+\delta))\ f(x)> c;$$
#
# funkcia $f$ má v bode $x_0$ **_nevlastnú limitu_** $-\infty$, ak
# $$(\forall c \in \mathbb{R})(\exists \delta > 0)(\forall x \in (x_0 - \delta,x_0+\delta))\ f(x)< c.$$
#
# ---

# %% [markdown]
# ---
#
# #### Poznámka 5
#
# * Definícia nevlastnej limity $+\infty$ v bode $x_0$ nám v podstate hovorí, že ak zvolíme hodnotu $c$ ľubovoľne veľkú, vždy k nej budeme vedieť nájsť také prstencové okolie bodu $x_0$, že pre $x$ z tohto okolia bude platiť $f(x)>c$. Inými slovami **ako sa blíži $x$ k $x_0$ tak $f(x)$ prevyšuje ľubovoľne veľké číslo**. **Podobne v prípade nevlastnej limity $-\infty$, $f(x)$ klesá pod akúkoľvek hranicu keď $x\to x_0$.**
#
#
# * Nevlastné limity sprava a zľava sa  definujú analogicky, ako v prípade vlastnej limity vo vlastnom bode (uvažuje sa $x \in (x_0,x_0+\delta)$ resp. $x \in (x_0 - \delta,x_0)$).
#
# ---

# %% [markdown]
# **Geometrický význam nevlastnej limity v bode**: pre každú priamku $y = c$  existuje okolo bodu $x_0$ interval polomeru $\delta$ taký, že úsek grafu funkcie vymedzený krajnými bodmi tohto intervalu leží celý nad (resp. pod - v prípade nevlastnej limity $-\infty$) danou priamkou.
#
# ![nevlastna_limita_geometricky.png](attachment:nevlastna_limita_geometricky.png)
# $$\text{Zdroj: Madaras (2019).}$$

# %% [markdown]
# ---
#
# #### Poznámka 6
#
# Ak funkcia $f$ má v bode $a$ nevlastnú limitu $+\infty$ alebo $-\infty$ tak priamku $x=a$ voláme **_vertikálna asymptota_** funkcie $f$. Viď napr. funkcia $f(x)=\dfrac{3x}{x^2-4}$ má vertikálne asymptoty $x=2$, $x=-2$.

# %%
x =  var('x')
kwds = {'fontsize':12} 
f = 3*x / (x^2-4) 
p1 = plot(f(x), (x, -6, -2.1), axes_labels=['$x$', '$y$'], axes_labels_size = 1.2) + text(r"$f(x)=\dfrac{3x}{x^2-4}$", (4, 15), color='blue',**kwds)
p2 = plot(f(x), (x, -1.9, 1.9), axes_labels=['$x$', '$y$'], axes_labels_size = 1.2) 
p3 = plot(f(x), (x, 2.1, 5), axes_labels=['$x$', '$y$'], axes_labels_size = 1.2) 
l1 = line([(-2,-15),(-2,15)], color = 'black', linestyle = 'dashed')
l2 = line([(2,-15),(2,15)], color = 'black', linestyle = 'dashed')  
show(l1+l2+p1+p2+p3)
# Out:
# Graphics object consisting of 6 graphics primitives

# %% [markdown]
# ---

# %% [markdown]
# ---
#
# #### Poznámka 7
#
# Všimnime si, že zatiaľ, čo funkcia $\dfrac{1}{x^2}$ má vertikálnu asymptotu $x=0$, nedá sa to isté povedať o funkcii $\dfrac{1}{x}$. Je to kvôli tomu, že správanie funkcie je iné v pravom a iné v ľavom okolí bodu $0$. Konkrétne teda platí $\lim\limits_{x\to0^+} \dfrac{1}{x}=\infty$ a $\lim\limits_{x\to0^-} \dfrac{1}{x}=-\infty$.
#
# ---

# %% [markdown]
# ---
#
# #### <font color=blue> Príklad 13  </font>
#
# Z definície dokážte, že $\lim\limits_{x \to 0} \dfrac{1}{x^2} = +\infty$.
#
# <ins> Riešenie: <ins/>
#
# Chceme dokázať, že
#
# $$(\forall c \in \mathbb{R})(\exists \delta > 0)(\forall x \in (- \delta,\delta))\ \dfrac{1}{x^2}> c.$$
#
# Nech $c \in \mathbb{R}$ je ľubovoľné kladné (pozn. $\dfrac{1}{x^2} > 0$ platí pre každé $x \neq 0$). Položme $\delta = \dfrac{1}{\sqrt{c}}$. Potom pre každé $x \in (-\delta, \delta)$ platí $|x| < \dfrac{1}{\sqrt{c}}$, teda $x^2 = |x|^2 < \dfrac{1}{c}$. Z toho vyplýva $\dfrac{1}{x^2} > c$.
#
#
# Ak by sme nechceli postupovať z definície limity, tak uvedený postup by bolo možné "obísť" aplikovaním Vety 10 a) (Premyslite si!).
#
# ---

# %% [markdown]
# ---
#
# ### <font color=red> Definícia 4 </font>
#
# Nech funkcia $f$ je definovaná na nejakom intervale $(a,\infty)$. Hovoríme, že funkcia $f$ má v bode $+\infty$ limitu rovnú $A$, ak
#
# $$(\forall \varepsilon > 0)(\exists k \in \mathbb{R}^+)(\forall x > k)\ |f(x) - A| < \varepsilon .$$
#
# Ak funkcia $f$ je definovaná na nejakom intervale $(-\infty,a)$, tak hovoríme, že funkcia $f$ má v bode $-\infty$  limitu rovnú $A$, ak
#
# $$(\forall \varepsilon > 0)(\exists k \in \mathbb{R}^-)(\forall x < k)\ |f(x) - A| < \varepsilon .$$
#
# ---

# %% [markdown]
# ---
#
# #### Poznámka 8
#
# * Symbolom $\mathbb{R}^-$ označujeme záporné reálne čísla, podobne symbolom $\mathbb{R}^+$ označujeme kladné reálne čísla.
#
#
# * Definícia **limity v nevlastnom bode** (t.j. v bode $+\infty$ alebo $-\infty$) v princípe hovorí, že ak zvolíme ľubovoľné $\varepsilon>0$, vždy k nemu existuje také $k>0$, že pre všetky $x$, ktoré sú (na reálnej osi) napravo od $k$ platí $|f(x)-A|<\varepsilon$, ináč povedané, keď $x$ "ide do nekonečna", tak funkcia $f(x)$ sa blíži k hodnote $A$ (ľubovoľne blízko sa k nej môže priblížiť, podľa toho ake $\varepsilon$ zvolíme). Analogicky je to v prípade, keď $x\to-\infty$, s tým rozdielom, že pozeráme na $x$ naľavo od $k$.
#
# ---

# %% [markdown]
# **Geometrický význam limity v nevlastnom bode:** pre každú šírku pásu (rovnú $2\varepsilon$, kde $\varepsilon$ je vzdialenosť okraja pásu od jeho pozdĺnej osi - prerušovaná čiara) s pozdĺžnou osou $y = A$ (horizontálna prerušovaná čiara) existuje bod $k$ taký, že úsek grafu funkcie napravo (resp. naľavo - v prípade limity pre $x \to -\infty$) leží celý vnútri daného pásu.
#
# ![limita_vnevlastnombode_geometricky.png](attachment:limita_vnevlastnombode_geometricky.png)
# $$\text{Zdroj: Madaras (2019).}$$

# %% [markdown]
# ---
#
# #### <font color=blue> Príklad 14  </font>
#
# Nech $P(t)$ vyjadruje celkový počet predaných kópii (v tisícoch kusov) novej aplikácie $t$ mesiacov po jej uvedení na trh. Niektoré hodnoty $P(t)$ sú uvedené v tabuľke nižšie a vo všeobecnosti je možné predajnosť aplikácie popísať takto:
#
# $$P(t)=\dfrac{532}{1+869e^{-0.8t}}.$$
#
#
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;}
# .tg td{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg th{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   font-weight:normal;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg .tg-baqh{text-align:center;vertical-align:top}
# .tg .tg-amwm{font-weight:bold;text-align:center;vertical-align:top}
# </style>
# <table class="tg">
# <thead>
#   <tr>
#     <th class="tg-amwm">$t$ (mesiace)</th>
#     <th class="tg-baqh">8</th>
#     <th class="tg-baqh">12</th>
#     <th class="tg-baqh">16</th>
#     <th class="tg-baqh">20</th>
#     <th class="tg-baqh">24</th>
#     <th class="tg-baqh">28</th>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <td class="tg-amwm">$P(t)$ (predaje v tisícoch)</td>
#     <td class="tg-baqh">217.685</td>
#     <td class="tg-baqh">502.429</td>
#     <td class="tg-baqh">530.727</td>
#     <td class="tg-baqh">531.948</td>
#     <td class="tg-baqh">531.998</td>
#     <td class="tg-baqh">531.999</td>
#   </tr>
# </tbody>
# </table>
#
#
# a) Na základe tabuľky odhadnite a a interpretujte $\lim\limits_{t\to\infty} P(t)$.
#
# b) Vypočítajte $\lim\limits_{t\to\infty} P(t)$ s využitím vzorca pre $P(t)$.
#
# <ins> Riešenie: <ins/>
#
# a) Z tabuľky sa zdá, že keď sa $t$ zväčšuje tak $P(t)$ sa blíži k hodnote $532$. To dáva zmysel, pretože v priebehu času je počet ľudí, ktorí sa zaujímajú o aplikáciu, obmedzený. Maximálny potenciálny (očakávaný) predaj tejto aplikácie sa teda odhaduje na $532$ tisíc.
#
# b) Keď $t$ rastie, tak výraz $e^{-0.8t}$ sa blíži k $0$, čiže $P(t)$ sa blíži k hodnote $532/(1+0)$. To naznačuje, že
#
# $$\lim\limits_{t\to\infty} \dfrac{532}{1+869e^{-0.8t}}=532.$$
#
# ---

# %% [markdown]
# ---
#
# ### <font color=green> Veta 8 </font>
#
# $\lim\limits_{x \to +\infty} f(x) = A$ práve vtedy, keď$\lim\limits_{y \to 0+} f\left ( \dfrac{1}{y} \right ) = A$.
#
# ---

# %% [markdown]
# ---
#
# #### <font color=blue> Príklad 15  </font>
#
# Vypočítajte $\lim\limits_{x\to\infty} \dfrac{1}{x}$.
#
# <ins> Riešenie: <ins/>
#
# Položme $f(x)=\dfrac{1}{x}$. Potom $f\left(\dfrac{1}{y}\right)=\dfrac{1}{\dfrac{1}{y}}=y$. Podľa Vety 3 a Vety 1 máme $\lim\limits_{x\to0^+} f\left(\dfrac{1}{y}\right)=\lim\limits_{x\to0^+}\dfrac{1}{\dfrac{1}{y}}=\lim\limits_{x\to0^+}y=0$. Veta 8 nám teda hovorí, že aj $\lim\limits_{x\to\infty} f(x)=\lim\limits_{x\to\infty}\dfrac{1}{x}=0$.

# %%
# kontrolny vypocet v Sage 
x,y = var('x,y')
print(limit(1/x,x=infinity))
print(limit(y,y=0,dir='+'))
# Out:
# 0
# 0

# %% [markdown]
# ---

# %% [markdown]
# ---
#
# #### Poznámka 9
#
# Ak funkcia $f$ má limitu $A$ v nevlastnom bode $+\infty$ alebo $-\infty$, potom priamku $y=A$ voláme **_horizontálna asymptota_** funkcie $f$. Viď napr. funkcia $f(x)=\dfrac{1}{x}$, ktorá má horizontálnu asymptotu $y=0$ (teda os x), lebo $\lim\limits_{x\to\infty} \dfrac{1}{x}=0$ a dokonca aj $\lim\limits_{x\to-\infty} \dfrac{1}{x}=0$.

# %%
x =  var('x')
kwds = {'fontsize':12} 
f = 1 / x 
p1 = plot(f(x), (x, -2, -0.05), axes_labels=['$x$', '$y$'], axes_labels_size = 1.2) + text(r"$f(x)=\dfrac{1}{x}$", (0.5, 20), color='blue',**kwds)
p2 = plot(f(x), (x, 0.05, 2), axes_labels=['$x$', '$y$'], axes_labels_size = 1.2) 
show(p1+p2)
# Out:
# Graphics object consisting of 3 graphics primitives

# %% [markdown]
# ---

# %% [markdown]
# ---
#
# ### <font color=green> Veta 9 </font>
#
# Nech funkcia $f$ je definovaná na intervale $(a, \infty)$. Ak $f$ je rastúca a zhora ohraničená na $(a,\infty)$ (resp. ak $f$ je klesajúca a zdola ohraničená na $(a, \infty)$), tak existuje vlastná limita $\lim\limits_{x \to \infty} f(x)$.
#
# ---

# %% [markdown]
# ---
#
# #### <font color=blue> Príklad 16  </font>
#
# Nech $f(x)=\mathrm{arctan}\,x$. Vypočítajte $\lim\limits_{x\to\infty} \mathrm{arctan}\,x$.
#
# <ins> Riešenie: <ins/>
#
# K výpočtu požadovanej limity chceme využiť Vetu 9. Na to, aby sme to mohli urobiť, by sme mali najprv overiť jej predpoklady, tzn. aby sme boli úplne dôslední, mali by sme z definície ukázať, že funkcia $f(x)=\mathrm{arctan}\,x$ je rastúca a ohraničená na nejakom intervale $(a,\infty)$. To je však záležitosťou MTIa, nebudeme to teraz robiť. (<font color=orange> Urobte to ako cvičenie! </font>). Vykreslíme si aspoň graf funkcie, aby sme o nej mali lepšiu predstavu.
#
# Veta 9 nám hovorí, že $\lim\limits_{x\to\infty} \mathrm{arctan}\,x$ existuje, no nehovorí, akej hodnote je príslušná limita rovná. V tomto prípade je limitou práve horizontálna asymptota $y=\dfrac{\pi}{2}$ t.j. $\lim\limits_{x\to\infty} \mathrm{arctan}\,x=\dfrac{\pi}{2}$. Exaktne by sme to mali zdôvodniť napr. z definície alebo použiť ešte nejakú ďalšiu matematickú vetu (tvrdenie) - pozri zoznam dôležitých limít na konci textu.

# %%
x =  var('x')
kwds = {'fontsize':12} 
f = arctan(x) 
p1 = plot(f(x), (x, -10, 10), axes_labels=['$x$', '$y$'], axes_labels_size = 1.2) + text(r"$f(x)=\mathrm{arctan}\,x$", (5, 1), color='blue',**kwds)
l1 = line([(-10,pi/2),(10,pi/2)], color = 'red', linestyle = 'dashed') + text(r"$y=\dfrac{\pi}{2}$", (-5, 2), color='red',**kwds)
show(p1+l1)
# Out:
# Graphics object consisting of 4 graphics primitives

# %% [markdown]
# ---

# %% [markdown]
# <font color=orange> Analogickým prístupom ako v Príklade 16 určte $\lim\limits_{x\to\infty} \left(1-\left(\dfrac{1}{3}\right)^x\right)$. Jednotlivé kroky zdôvodnite. </font>

# %% [markdown]
# ---
#
# ### <font color=green> Veta 10 </font>
#
# Nech $\lim\limits_{x \to x_0} f(x) \neq 0, \lim\limits_{x \to x_0} g(x) = 0$ a nech existuje také okolie $x_0$, že pre každé  $x$ z tohto okolia, $x \neq x_0$ je $g(x) > 0$. Potom
#
# a) ak $\lim\limits_{x \to x_0} f(x) > 0$, tak $\lim\limits_{x \to x_0} \dfrac{f(x)}{g(x)} = +\infty$;
#
#
# b) ak $\lim\limits_{x \to x_0} f(x) < 0$, tak $\lim\limits_{x \to x_0} \dfrac{f(x)}{g(x)} = -\infty$.
#
# ---

# %% [markdown]
# ---
#
# #### <font color=blue> Príklad 17  </font>
#
# Vypočítajte limitu $\lim\limits_{x \to 1} \dfrac{x}{(x-1)^2}$.
#
# <ins> Riešenie: <ins/>
#
# Je vhodné vykresliť si graf tejto funkcie. Ďalej položme $f(x)=x$ a $g(x)=(x-1)^2$. Aj grafy týchto funkcií je dobré mať pred očami. Vďaka Vete 3 platí $\lim\limits_{x \to 1} x = 1\neq0$, čiže podmienka z Vety 10 ohľadom funkcie $f$ je splnená.
# Ďalej podobne podľa Vety 3 platí $\lim\limits_{x \to 1} (x-1)^2 = 0$. Navyše ak zoberieme nejaké prstencové okolie bodu $1$ tak funkcia $g(x)$ je kladná pre všetky $x$ (okrem $1$) z tohto prstencového okolia. Je teda splnená aj podmienka pre funkciu $g(x)$ z Vety 10. Podľa časti a) Vety 10 platí $\lim\limits_{x \to 1} \dfrac{f(x)}{g(x)} = \lim\limits_{x \to 1} \dfrac{x}{(x-1)^2} = +\infty$.

# %%
# kontrolny vypocet v Sage 
limit(x/(x-1)^2,x=1)
# Out:
# +Infinity

# %% [markdown]
# <font color=orange> Aplikujte Vetu 10 a) na výpočet limity v Príklade 13. Presne popíšte splnenie predpokladov Vety 10 pre limitu v Príklade 13 - tzn. určte funkcie $f(x)$, $g(x)$, bod $x_0$ a jeho prstencové okolie, na ktorom je $g(x)>0$ a tiež zdôvodnite, že $\lim\limits_{x \to x_0} f(x) > 0$. </font>

# %% [markdown]
# ---

# %% [markdown]
# Ako posledný prípad ostáva situácia, keď $x \to +\infty$ alebo $x \to -\infty$ a funkcia má nevlastnú limitu $+\infty$ alebo $-\infty$. Ako príklad uvádzame graf funkcie $f(x)=x^2$, kde pre $x\to+\infty$ máme $f(x)\to+\infty$, čo budeme označovať $\lim\limits_{x\to+\infty} f(x) = \lim\limits_{x\to+\infty} x^2=+\infty$. Platí tiež $\lim\limits_{x\to-\infty} f(x) = \lim\limits_{x\to-\infty} x^2=+\infty$.

# %%
x =  var('x')
kwds = {'fontsize':12} 
f = x^2
p1 = plot(f(x), (x, -4, 4), axes_labels=['$x$', '$y$'], axes_labels_size = 1.2) + text(r"$f(x)=x^2$", (3, 15), color='blue',**kwds)
show(p1)
# Out:
# Graphics object consisting of 2 graphics primitives

# %% [markdown]
# ---
#
# ### <font color=red> Definícia 5 </font>
#
# Nech funkcia $f$ je definovaná na nejakom intervale $(a,\infty)$ (resp. $(-\infty,a)$).
# Hovoríme, že:
#
# funkcia $f$ má v bode $+\infty$ nevlastnú limitu $+\infty$, ak
# $$(\forall c \in \mathbb{R})(\exists k \in \mathbb{R}^+)(\forall x > k)\ f(x)> c;$$
#
#
# funkcia $f$ má v bode $+\infty$ nevlastnú limitu $-\infty$, ak
# $$(\forall c \in \mathbb{R})(\exists k \in \mathbb{R}^+)(\forall x >k)\ f(x)< c;$$
#
#
# funkcia $f$ má v bode $-\infty$ nevlastnú limitu $+\infty$, ak
# $$(\forall c \in \mathbb{R})(\exists k \in \mathbb{R}^-)(\forall x <k)\ f(x)> c;$$
#
#
# funkcia $f$ má v bode $-\infty$ nevlastnú limitu $-\infty$, ak
# $$(\forall c \in \mathbb{R})(\exists k \in \mathbb{R}^-)(\forall x <k)\ f(x)< c.$$
#
# ---

# %% [markdown]
# ---
#
# #### Poznámka 10
#
# Definícia nevlastnej limity $+\infty$ v nevlastnom bode $+\infty$ hovorí, že ak zvolíme ľubovoľné $c\in\mathbb{R}$, tak vieme k nemu nájsť také $k>0$, že pre všetky $x>k$ bude platiť $f(x)>c$, ináč povedané, pre $x\to+\infty$ funkcia $f(x)$ rastie neobmedzene t.j. $f(x)\to+\infty$.
# Ostatné nevlastné limity v nevlastných bodoch je možné interpretovať podobne.
#
# ---

# %% [markdown]
# ---
#
# #### <font color=blue> Príklad 18  </font>
#
# Nech $f(x)=x^2$. Dokážte, že $\lim\limits_{x\to+\infty} f(x)=\lim\limits_{x\to+\infty} x^2 = +\infty$.
#
# <ins> Riešenie: <ins/>
#
# Podľa Definície 5 potrebujeme ukázať, že nech vezmeme akékoľvek reálne číslo $c$, existuje k nemu také kladné číslo $k$, že pre všetky $x$ väčšie ako $k$ bude platiť $f(x)>c$. Postup riešenia rozdelíme na dve časti, najprv sa pozrieme na prípad $c\le0$ a potom na $c>0$. <br/>
# Ak by sme uvažovali $c \le 0$, tak keďže $x^2 \ge 0$ pre všetky $x\in\mathbb{R}$ a $x^2=0$ iba pre $x=0$, mohli by sme vziať ľubovoľné $k>0$, napr. $k=1$ a potom pre všetky $x>1$ by platilo $x^2>c$. <br/>
# Uvažujme teraz $c>0$. Položme $k=\sqrt{c+1}$. Potom pre $x>k$ platí nasledovné: $x^2 > k^2 = c+1 > c$ odkiaľ máme $x^2 > c$, čo bolo potrebné dokázať.
#
#
# Uvedený postup je možné "obísť" tak, že aplikujeme predposledný poznatok zo zoznamu limít na konci učebného textu. Pri tom je potrebné si uvedomiť, že platí $f(x)=\dfrac{x^2}{1}$, a teda v čitateli zlomku je polynóm druhého stupňa $n=2$, v menovateli je konštanta - t.j. polynóm nultého stupňa, preto $m=0$.

# %%
# limita funkcie x^2 pre x iduce do +nekonecna 
show(limit(x^2,x=infinity))
# Out:
# +Infinity

# %%
x =  var('x')
kwds = {'fontsize':12} 
f = x^2
p1 = plot(f(x), (x, -4, 4), axes_labels=['$x$', '$y$'], axes_labels_size = 1.2) + text(r"$f(x)=x^2$", (3, 15), color='blue',**kwds)
show(p1)
# Out:
# Graphics object consisting of 2 graphics primitives

# %% [markdown]
# ---

# %% [markdown]
# V závere ešte sumarizujeme niektoré užitočné **tvrdenia pre výpočet špeciálnych limít**. **Tieto tvrdenia je možné aplikovať pri práci s nevlastnými limitami funkcií vo vlastnom aj nevlastnom bode.**

# %% [markdown]
# ---
#
# ### <font color=green> Veta 11 </font>
#
# Nech $\lim\limits_{x \to x_0} f(x) = +\infty$, $\lim\limits_{x \to x_0} g(x) = +\infty$ a funkcia $h$ je zdola ohraničená na nejakom prstencovom okolí bodu $x_0$, pričom $x_0\in\mathbb{R}\cup\{+\infty,-\infty\}$. Potom platí
#
# a) $\lim\limits_{x \to x_0} \left(f(x)+g(x)\right) = +\infty$;
#
#
# b) $\lim\limits_{x \to x_0} \left(f(x)\cdot g(x)\right) = +\infty$;
#
#
# c) $\lim\limits_{x \to x_0} \left(f(x)+h(x)\right) = +\infty$;
#
#
# d) Ak funkcia $h$ je zdola ohraničená kladnou konštantou na nejakom prstencovom okolí bodu $x_0$, tak $\lim\limits_{x \to x_0} \left(f(x)\cdot h(x)\right) = +\infty$.
#
# ---

# %% [markdown]
# ---
#
# #### Poznámka 11
#
# Taktiež platia aj alternatívne tvrdenia k tvrdeniam c), d) vo Vete 11:
#
# * Ak funkcia $h$ je zhora ohraničená na nejakom prstencovom okolí bodu $x_0$ a $\lim\limits_{x \to x_0} f(x) = -\infty$, tak $\lim\limits_{x \to x_0} \left(f(x)+h(x)\right) = -\infty$.
#
#
# * Ak funkcia $h$ je zdola ohraničená kladnou konštantou na nejakom prstencovom okolí bodu $x_0$ a $\lim\limits_{x \to x_0} f(x) = -\infty$, tak $\lim\limits_{x \to x_0} \left(f(x)\cdot h(x)\right) = -\infty$.
#
# ---

# %% [markdown]
# ---
#
# ### <font color=green> Veta 12 </font>
#
# Ak $\lim\limits_{x \to x_0} |f(x)|=+\infty$, kde $x_0\in\mathbb{R}\cup\{+\infty, -\infty\}$, potom
#
# $$\lim\limits_{x \to x_0} \frac{1}{f(x)}=0.$$
#
# ---

# %% [markdown]
# ![tabulka_limit.png](attachment:tabulka_limit.png)
# $$\text{Zdroj: Madaras (2019).}$$
#
# Legenda: riadky zodpovedajú možnostiam pre hodnotu $\lim\limits_{x \to x_0} f(x)$, stĺpce možnostiam pre hodnotu $\lim\limits_{x \to x_0} g(x)$ (kladná, nulová, záporná, $+\infty,-\infty$), jednotlivé polia sú výsledné hodnoty limity súčtu, rozdielu (horné polia), súčinu a podielu (dolné polia) funkcií $f,g$ v bode $x_0$; "?" symbolizuje nejednoznačný (alebo nedefinovaný ako napr. $+\infty-\infty$) výsledok.

# %% [markdown]
# **Zoznam dôležitých limít (bez odvodenia):**
#
# * $\lim\limits_{x \to 0} \dfrac{\sin x}{x} = 1$;
#
#
# * $\lim\limits_{x \to 0} \dfrac{\mathrm{tg}\, x}{x} = 1$;
#
#
# * $\lim\limits_{x \to 0} a^x = 1$ pre $a > 0$;
#
#
# * $\lim\limits_{x \to \infty} a^x = \begin{cases}
# \ \infty, \qquad a > 1\\
# \ 0, \qquad 0 < a < 1
# \end{cases}$;
#
# * $\lim\limits_{x \to \infty} \left ( 1 + \dfrac{1}{x} \right )^x = e \doteq 2,71828\dots$;
#
#
# * $\lim\limits_{x \to 0+} (1+x)^{\frac{1}{x}} = e$;
#
#
# * $\lim\limits_{x \to -\infty} \left ( 1+\dfrac{1}{x} \right )^x = e$;
#
#
# * $\lim\limits_{x \to 0-} (1+x)^{\frac{1}{x}} = e$;
#
#
# * $\lim\limits_{x \to 0} \dfrac{e^x-1}{x} = 1$;
#
#
# * $\lim\limits_{x \to 0} \dfrac{a^x-1}{x} = \ln a$ pre $a>0$;
#
#
# * $\lim\limits_{x \to \infty} \dfrac{x^n}{a^x} = 0$ pre $n \in \mathbb{R}, x > 0, a > 1$;
#
#
# * $\lim\limits_{x \to \infty} \sqrt[x]{x} = 1$;
#
#
# * $\lim\limits_{x \to +\infty} \mathrm{arctg}\, x = \dfrac{\pi}{2}$;
#
#
# * $\lim\limits_{x \to -\infty} \mathrm{arctg}\, x = -\dfrac{\pi}{2}$;
#
#
# * $\lim\limits_{x \to +\infty} \mathrm{arccotg}\, x = 0$;
#
#
# * $\lim\limits_{x \to -\infty} \mathrm{arccotg}\, x = \pi$;
#
#
# * $\lim\limits_{x \to \infty} \dfrac{x^{\alpha}}{e^{\beta x}} = 0$ pre $\alpha,\beta>0$;
#
#
# *  $\lim\limits_{x \to +\infty} \dfrac{a_nx^n + a_{n-1}x^{n-1} + \dots + a_1x + a_0}{b_mx^m + b_{m-1}x^{m-1} + \dots + b_1 x + b_0} = \begin{cases}
# 0, \qquad\quad m > n \\
# +\infty, \qquad m < n, \dfrac{a_n}{b_m} > 0 \\
# -\infty, \qquad m < n, \dfrac{a_n}{b_m} < 0 \\
# \dfrac{a_n}{b_m}, \qquad m = n
# \end{cases}$;
#
#
# *  $\lim\limits_{x \to -\infty} \dfrac{a_nx^n + a_{n-1}x^{n-1} + \dots  + a_0}{b_mx^m + b_{m-1}x^{m-1} + \dots  + b_0} = \begin{cases}
# 0, \qquad\quad  m > n \\
# +\infty, \qquad m < n, (-1)^{n-m}\dfrac{a_n}{b_m} > 0 \\
# -\infty, \qquad m < n, (-1)^{n-m}\dfrac{a_n}{b_m} < 0 \\
# \dfrac{a_n}{b_m}, \qquad m = n
# \end{cases}$.

# %% [markdown]
# ***
# <a id=zdroje></a>
#  # <font color=brown> Použité zdroje</font>

# %% [markdown]
# * Boelkins M., Austin D., Schlicker S. (2018). Active Calculus. 978-1085940856.
#
#
# * Goldstein L. J. et al. (2017). Calculus & Its Applications. Pearson Education.
#
#
# * Hartman G. et al. (2018). APEX Calculus. 978-1514225158.
#
#
# * Hallet D. H. et al. (2017). Calculus: Single Variable. Wiley.
#
#
# * Hallet D. H. (2014). Applied Calculus. John Wiley & Sons.
#
#
# * [Prednáška](https://umv.science.upjs.sk/madaras/MZIa/MZIa2011_8.pdf) prof. Madaras.
